# %%
# libraries
import os
import getpass
import numpy as np
import pandas as pd
import seaborn as sns
from functools import reduce
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduktion
# Formålet med denne kode ...

# %% [markdown]
# # Funktioner

# %% [markdown]
# ## Header

# %%
def standardize_dates(df, date_column):
    """
    Standardizes a date column to a common monthly format (YYYY-MM-01).
    
    Parameters:
    df (pd.DataFrame): The dataframe containing the date column.
    date_column (str): The name of the column containing date values.
    Returns:
    pd.DataFrame: The dataframe with a standardized date column.
    """
    
    # Make a copy of the dataframe to avoid modifying the original
    df = df.copy()
    
    # Convert to string in case of mixed formats
    df[date_column] = df[date_column].astype(str)
    
    # Handle daily format (YYYY-MM-DD) → Convert directly
    if df[date_column].str.match(r"^\d{4}-\d{2}-\d{2}$").all():
        df["Date"] = pd.to_datetime(df[date_column]).dt.to_period("M").dt.to_timestamp()

    # Handle monthly format (YYYY-MM) → Convert directly
    elif df[date_column].str.match(r"^\d{4}-\d{2}$").all():
        df["Date"] = pd.to_datetime(df[date_column] + "-01")
        
    # Handle monthly format (YYYYMM) → Convert directly
    elif df[date_column].str.match(r"^\d{4}\d{2}$").all():
        df["Date"] = pd.to_datetime(df[date_column] + "-01")
        
    # Handle daliy format (YYYYM0DD)
    elif df[date_column].str.match(r"^\d{4}M0\d{2}$").all():
        df["Date"] = pd.to_datetime(df[date_column].str[:4] + "-" + df[date_column].str[5:6] + "-" + df[date_column].str[-2:])

    # Handle monthly format (YYYYMM) → Convert correctly
    elif df[date_column].str.match(r"^\d{4}M\d{2}$").all():
        df["Date"] = pd.to_datetime(df[date_column].str[:4] + "-" + df[date_column].str[5:] + "-01")
        
    # Handle yearly format (YYYY) → Convert to first day of the year
    elif df[date_column].str.match(r"^\d{4}$").all():
        df["Date"] = pd.to_datetime(df[date_column] + "-01-01")
        
    # Handle format 'YYYYMXXDXX' (e.g., '2001M01D02' → '2001-01-02')
    elif df[date_column].str.match(r"^\d{4}M\d{2}D\d{2}$").all():
        df["Date"] = pd.to_datetime(
            df[date_column].str[:4] + "-" +  # Extract year
            df[date_column].str[5:7] + "-" +  # Extract month (skip 'M')
            df[date_column].str[-2:]  # Extract day (skip 'D')
        )

    # Handle quarterly format (YYYYKX) → Convert to first month of quarter
    elif df[date_column].str.match(r"^\d{4}K[1-4]$").all():
        df["Date"] = pd.to_datetime(
            df[date_column].str[:4] + "-" + 
            df[date_column].str[5].replace({"1": "01", "2": "04", "3": "07", "4": "10"}) + "-01"
        )
        
    elif df[date_column].str.match(r"^\d{4}K[1-4]$").all():
        quarter_map = {"1": "01", "2": "04", "3": "07", "4": "10"}
        df["Date"] = pd.to_datetime(
            df[date_column].str[:4] + "-" +
            df[date_column].str[5].map(quarter_map) + "-01"
        )

    
    else:
        raise ValueError("Unrecognized date format. Ensure the column is in daily (YYYY-MM-DD), monthly (YYYY-MM), or quarterly (YYYYKX) format.")
    
    # Drop the original date column and set the new Date column as index
    df = df.drop(columns=[date_column]).set_index("Date")
    
    return df

def save_merged_data(df, filename="merged_dataset.csv"):
    """
    Gemmer en dataframe som en CSV-fil.
    
    Parameters:
    df (pd.DataFrame): DataFrame der skal gemmes.
    filename (str): Navnet på den gemte CSV-fil (standard: "merged_dataset.csv").
    """
    df.to_csv(filename, sep=";", na_rep="NaN", index=True, encoding="utf-8")
    print(f"✅ Filen '{filename}' er gemt!")

    
def check_missing_values(df):
    missing_values = df.isna().sum()  # Antal NaN per kolonne
    total_missing = missing_values.sum()  # Samlet antal NaN
    missing_percent = (missing_values / len(df)) * 100  # Procentvis manglende værdier
    
    # Udlad for nu
    missing_df = pd.DataFrame({
        "Missing Values": missing_values,
        "Percentage (%)": missing_percent
    })
    
    print(f"Total missing values in dataset: {total_missing}")
    return

# %% [markdown]
# ## Import headers

# %%
# Gå et niveau op og naviger til mappen "Data"
os.chdir('Data')

# Læs headeren fra "header.csv"
header_path = 'header.csv'
header = pd.read_csv(header_path, sep=';', encoding='ISO-8859-1').columns.tolist()

# %% [markdown]
# ## Niveau 0

# %%
# Åbn CSV-filen "niveau_0" som er semikolon-separeret og med encoding 'ISO-8859-1'
file_path = 'niveau_0.csv'
niveau_0 = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1',header=0)

niveau_0.replace("..", pd.NA, inplace=True)

# Kør standardiseringsfunktionen
df_niveau_0 = standardize_dates(niveau_0, "date")

# Se det nye dataset
df_niveau_0
# Out:
#             00 Forbrugerprisindekset i alt
# Date
# 2001-01-01                            76.7
# 2001-02-01                            77.3
# 2001-03-01                            77.7
# 2001-04-01                            78.0
# 2001-05-01                            78.4
# ...                                    ...
# 2024-10-01                           119.6
# 2024-11-01                           119.2
# 2024-12-01                           118.9
# 2025-01-01                           119.6
# 2025-02-01                           120.8
#
# [290 rows x 1 columns]

# %%
check_missing_values(df_niveau_0)
# Out:
# Total missing values in dataset: 0

# %% [markdown]
# ## Niveau 1

# %%
# Åbn CSV-filen "niveau_1" som er semikolon-separeret og med encoding 'ISO-8859-1'
file_path = 'niveau_1_new.csv'
niveau_1 = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0).dropna()
niveau_1.replace("..", pd.NA, inplace=True)

# %%
# Kør standardiseringsfunktionen
df_niveau_1 = standardize_dates(niveau_1, "date")
df_niveau_1
# Out:
#             01 Fødevarer og ikke-alkoholiske drikkevarer  \
# Date
# 2001-01-01                                          75.2
# 2001-02-01                                          75.7
# 2001-03-01                                          76.2
# 2001-04-01                                          77.0
# 2001-05-01                                          77.5
# ...                                                  ...
# 2024-10-01                                         132.4
# 2024-11-01                                         132.4
# 2024-12-01                                         129.7
# 2025-01-01                                         132.6
# 2025-02-01                                         133.7
#
#             02. Alkoholiske drikkevarer og tobak  03. Beklædning og fodtøj  \
# Date
# 2001-01-01                                  76.3                      88.9
# 2001-02-01                                  76.3                      89.7
# 2001-03-01                                  76.4                      97.4
# 2001-04-01                                  76.4                     100.0
# 2001-05-01                                  76.5                     100.1
# ...                                          ...                       ...
# 2024-10-01                                 135.0                      99.7
# 2024-11-01                                 134.8                      98.6
# 2024-12-01                                 132.5                      98.5
# 2025-01-01                                 136.8                      91.8
# 2025-02-01                                 135.7                      94.0
#
#             04. Boligbenyttelse, elektricitet og opvarmning  \
# Date
# 2001-01-01                                             69.4
# 2001-02-01                                             70.2
# 2001-03-01                                             70.1
# 2001-04-01                                             70.2
# 2001-05-01                                             70.2
# ...                                                     ...
# 2024-10-01                                            120.2
# 2024-11-01                                            121.0
# 2024-12-01                                            120.7
# 2025-01-01                                            121.3
# 2025-02-01                                            123.0
#
#             05. Møbler, husholdningsudstyr og husholdningstjenester  \
# Date
# 2001-01-01                                               84.7
# 2001-02-01                                               85.2
# 2001-03-01                                               85.5
# 2001-04-01                                               85.7
# 2001-05-01                                               85.8
# ...                                                       ...
# 2024-10-01                                              101.6
# 2024-11-01                                              103.7
# 2024-12-01                                              104.1
# 2025-01-01                                              102.7
# 2025-02-01                                              103.6
#
#             06. Sundhed  07. Transport  08. Kommunikation  \
# Date
# 2001-01-01         81.2           77.7              130.4
# 2001-02-01         81.2           78.5              130.2
# 2001-03-01         81.2           78.4              129.7
# 2001-04-01         80.0           79.0              129.4
# 2001-05-01         80.0           80.0              129.1
# ...                 ...            ...                ...
# 2024-10-01        113.8          118.7               84.9
# 2024-11-01        112.4          117.7               84.3
# 2024-12-01        113.8          117.6               85.9
# 2025-01-01        113.7          119.1               85.0
# 2025-02-01        114.4          119.9               86.3
#
#             09. Fritid og kultur  10. Uddannelse  \
# Date
# 2001-01-01                  96.7            49.8
# 2001-02-01                  96.8            49.8
# 2001-03-01                  96.9            49.8
# 2001-04-01                  97.4            49.8
# 2001-05-01                  98.3            49.8
# ...                          ...             ...
# 2024-10-01                 116.3           134.6
# 2024-11-01                 115.0           134.6
# 2024-12-01                 113.8           134.6
# 2025-01-01                 114.4           135.2
# 2025-02-01                 117.3           135.2
#
#             11. Restauranter og hoteller  12. Andre varer og tjenester
# Date
# 2001-01-01                          70.4                          68.1
# 2001-02-01                          70.7                          68.2
# 2001-03-01                          70.8                          68.5
# 2001-04-01                          70.9                          68.9
# 2001-05-01                          71.2                          69.4
# ...                                  ...                           ...
# 2024-10-01                         133.7                         120.1
# 2024-11-01                         128.6                         119.9
# 2024-12-01                         131.6                         119.9
# 2025-01-01                         131.7                         122.5
# 2025-02-01                         132.2                         122.4
#
# [290 rows x 12 columns]

# %%
check_missing_values(df_niveau_1)
# Out:
# Total missing values in dataset: 0

# %% [markdown]
# ## Niveau 2

# %%
# First approch, I think it can be delete at some point...
""" # Åbn CSV-filen "niveau_2" som er semikolon-separeret og med encoding 'ISO-8859-1'
file_path = 'niveau_2_new.csv'
niveau_2 = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0, decimal=",")
niveau_2.replace("..", pd.NA, inplace=True)
niveau_2.head()

# Kør standardiseringsfunktionen
df_niveau_2 = standardize_dates(niveau_2, "date")
df_niveau_2

# Check Missing values
check_missing_values(df_niveau_2)

# Fjern kolonnen "01.1 Fødevarer"
#df_niveau_2 = df_niveau_2.drop(columns=["01.1 Fødevarer"])


# Print all for each columns the sum of NaNs
print(df_niveau_2.isna().sum())


# Hvis en række har mere en 70 pct NaN slettes den
# Ændre til 100pct
df_niveau_2.dropna(axis=1, thresh=len(df_niveau_2) * 1, inplace=True) """
# Out:
# ' # Åbn CSV-filen "niveau_2" som er semikolon-separeret og med encoding \'ISO-8859-1\'\nfile_path = \'niveau_2_new.csv\'\nniveau_2 = pd.read_csv(file_path, sep=\';\', encoding=\'ISO-8859-1\', header=0, decimal=",")\nniveau_2.replace("..", pd.NA, inplace=True)\nniveau_2.head()\n\n# Kør standardiseringsfunktionen\ndf_niveau_2 = standardize_dates(niveau_2, "date")\ndf_niveau_2\n\n# Check Missing values\ncheck_missing_values(df_niveau_2)\n\n# Fjern kolonnen "01.1 Fødevarer"\n#df_niveau_2 = df_niveau_2.drop(columns=["01.1 Fødevarer"])\n\n\n# Print all for each columns the sum of NaNs\nprint(df_niveau_2.isna().sum())\n\n\n# Hvis en række har mere en 70 pct NaN slettes den\n# Ændre til 100pct\ndf_niveau_2.dropna(axis=1, thresh=len(df_niveau_2) * 1, inplace=True) '

# %%
file_path = 'niveau_2.xlsx'
niveau_2 = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
niveau_2 = standardize_dates(niveau_2, "date")

# %%
df_niveau_2 = niveau_2.resample("MS").ffill()
df_niveau_2
# Out:
#             01.1 Fødevarer  01.2 Ikke-alkoholiske drikkevarer  \
# Date
# 2001-01-01            74.7                               79.4
# 2001-02-01            75.0                               80.6
# 2001-03-01            75.6                               81.1
# 2001-04-01            76.6                               80.7
# 2001-05-01            77.1                               80.6
# ...                    ...                                ...
# 2024-10-01           134.1                              119.5
# 2024-11-01           134.3                              118.5
# 2024-12-01           131.7                              115.4
# 2025-01-01           133.9                              122.1
# 2025-02-01           134.9                              124.2
#
#             02.1 Alkoholiske drikkevarer  02.2 Tobak  03.1 Beklædning  \
# Date
# 2001-01-01                          88.9        66.8             96.6
# 2001-02-01                          89.0        66.8             98.0
# 2001-03-01                          89.2        66.8            107.8
# 2001-04-01                          89.2        66.8            110.9
# 2001-05-01                          89.3        66.8            110.9
# ...                                  ...         ...              ...
# 2024-10-01                         114.1       157.0             95.8
# 2024-11-01                         113.8       157.0             94.6
# 2024-12-01                         110.2       157.3             94.6
# 2025-01-01                         115.8       157.6             87.8
# 2025-02-01                         114.1       158.1             90.2
#
#             03.2 Fodtøj  04.1 Faktisk husleje  \
# Date
# 2001-01-01         61.5                  69.7
# 2001-02-01         60.9                  71.1
# 2001-03-01         62.6                  71.1
# 2001-04-01         63.8                  71.1
# 2001-05-01         63.9                  71.1
# ...                 ...                   ...
# 2024-10-01        115.8                 115.2
# 2024-11-01        115.5                 115.6
# 2024-12-01        114.6                 115.6
# 2025-01-01        108.8                 115.6
# 2025-02-01        110.1                 117.2
#
#             04.2 Beregnet lejeværdi af bolig  \
# Date
# 2001-01-01                              69.6
# 2001-02-01                              71.0
# 2001-03-01                              71.0
# 2001-04-01                              71.0
# 2001-05-01                              71.0
# ...                                      ...
# 2024-10-01                             115.6
# 2024-11-01                             116.0
# 2024-12-01                             116.0
# 2025-01-01                             116.0
# 2025-02-01                             117.6
#
#             04.3 Vedligeholdelse og reparation af bolig  \
# Date
# 2001-01-01                                         73.9
# 2001-02-01                                         75.0
# 2001-03-01                                         75.1
# 2001-04-01                                         75.1
# 2001-05-01                                         75.5
# ...                                                 ...
# 2024-10-01                                        133.7
# 2024-11-01                                        134.4
# 2024-12-01                                        134.8
# 2025-01-01                                        134.9
# 2025-02-01                                        135.0
#
#             04.4 Vandforsyning og andre tjenester i forbindelse med boligen  \
# Date
# 2001-01-01                                               60.2
# 2001-02-01                                               60.2
# 2001-03-01                                               60.2
# 2001-04-01                                               60.2
# 2001-05-01                                               60.2
# ...                                                       ...
# 2024-10-01                                              125.8
# 2024-11-01                                              125.8
# 2024-12-01                                              125.8
# 2025-01-01                                              132.4
# 2025-02-01                                              132.4
#
#             ...  10.4 Videregående uddannelse  \
# Date        ...
# 2001-01-01  ...                           NaN
# 2001-02-01  ...                           NaN
# 2001-03-01  ...                           NaN
# 2001-04-01  ...                           NaN
# 2001-05-01  ...                           NaN
# ...         ...                           ...
# 2024-10-01  ...                         127.7
# 2024-11-01  ...                         127.7
# 2024-12-01  ...                         127.7
# 2025-01-01  ...                         129.1
# 2025-02-01  ...                         129.1
#
#             10.5 Undervisning uden for niveau  \
# Date
# 2001-01-01                                NaN
# 2001-02-01                                NaN
# 2001-03-01                                NaN
# 2001-04-01                                NaN
# 2001-05-01                                NaN
# ...                                       ...
# 2024-10-01                              131.6
# 2024-11-01                              131.6
# 2024-12-01                              131.6
# 2025-01-01                              133.7
# 2025-02-01                              133.7
#
#             11.1 Restauranter, cafeer og kantiner mv.  \
# Date
# 2001-01-01                                       69.7
# 2001-02-01                                       70.1
# 2001-03-01                                       70.2
# 2001-04-01                                       70.3
# 2001-05-01                                       70.4
# ...                                               ...
# 2024-10-01                                      131.5
# 2024-11-01                                      131.8
# 2024-12-01                                      132.0
# 2025-01-01                                      132.5
# 2025-02-01                                      133.1
#
#             11.2 Overnatningsfaciliteter  12.1 Personlig pleje  \
# Date
# 2001-01-01                          82.0                  78.4
# 2001-02-01                          82.0                  78.4
# 2001-03-01                          82.0                  79.1
# 2001-04-01                          82.0                  79.4
# 2001-05-01                          85.6                  79.5
# ...                                  ...                   ...
# 2024-10-01                         142.2                 103.7
# 2024-11-01                         111.2                 103.0
# 2024-12-01                         127.5                 102.7
# 2025-01-01                         125.1                 103.4
# 2025-02-01                         125.3                 102.6
#
#             12.3 Andre personlige effekter  \
# Date
# 2001-01-01                            72.3
# 2001-02-01                            72.8
# 2001-03-01                            73.9
# 2001-04-01                            74.1
# 2001-05-01                            74.5
# ...                                    ...
# 2024-10-01                           101.9
# 2024-11-01                           101.9
# 2024-12-01                           102.5
# 2025-01-01                           100.1
# 2025-02-01                           101.6
#
#             12.4 Daginstitutioner og social forsorg  12.5 Forsikring  \
# Date
# 2001-01-01                                     70.6             62.1
# 2001-02-01                                     70.6             62.1
# 2001-03-01                                     70.6             62.1
# 2001-04-01                                     70.6             62.1
# 2001-05-01                                     70.6             63.5
# ...                                             ...              ...
# 2024-10-01                                    130.4            123.4
# 2024-11-01                                    130.4            123.4
# 2024-12-01                                    130.4            123.4
# 2025-01-01                                    138.1            128.3
# 2025-02-01                                    138.1            128.3
#
#             12.6 Finansielle tjenester  12.7 Andre tjenester
# Date
# 2001-01-01                        62.3                  66.1
# 2001-02-01                        62.3                  66.1
# 2001-03-01                        62.3                  66.4
# 2001-04-01                        65.9                  67.7
# 2001-05-01                        66.2                  67.7
# ...                                ...                   ...
# 2024-10-01                       127.4                 124.8
# 2024-11-01                       127.4                 124.9
# 2024-12-01                       127.9                 124.9
# 2025-01-01                       128.0                 125.4
# 2025-02-01                       127.4                 126.1
#
# [290 rows x 44 columns]

# %% [markdown]
# ## Inflation

# %%
file_path = 'cpi_inflation.xlsx'
cpi = pd.read_excel(file_path, header=0, decimal=",")
cpi
# Out:
#         date    cpi
# 0    2001M01   76.7
# 1    2001M02   77.3
# 2    2001M03   77.7
# 3    2001M04   78.0
# 4    2001M05   78.4
# ..       ...    ...
# 285  2024M10  119.6
# 286  2024M11  119.2
# 287  2024M12  118.9
# 288  2025M01  119.6
# 289  2025M02  120.8
#
# [290 rows x 2 columns]

# %%
cpi = standardize_dates(cpi, "date")

# %%
# Beregn inflation som år-til-år ændring (i procent)
cpi["Inflation"] = ((cpi["cpi"] - cpi["cpi"].shift(12)) / cpi["cpi"].shift(12)) * 100

# Rund til 4 decimaler (valgfrit)
cpi["Inflation"] = cpi["Inflation"].round(3)

cpi = cpi.drop(columns=["cpi"])

df_inflation = cpi.copy()

# %%
df_inflation
# Out:
#             Inflation
# Date
# 2001-01-01        NaN
# 2001-02-01        NaN
# 2001-03-01        NaN
# 2001-04-01        NaN
# 2001-05-01        NaN
# ...               ...
# 2024-10-01      1.614
# 2024-11-01      1.620
# 2024-12-01      1.885
# 2025-01-01      1.528
# 2025-02-01      2.027
#
# [290 rows x 1 columns]

# %% [markdown]
# ### Lagged af inflation

# %%
# Antag, at din originale dataframe hedder 'df_inflation'
# og at kolonnen hedder som vist på billedet
colname = "Inflation"

# Hvor mange lags du vil have med
num_lags = 12

# Lav en kopi, så vi ikke ændrer det oprindelige
df_lagged_inflation = df_inflation[[colname]].copy()

# Lav laggede kolonner
for lag in range(1, num_lags + 1):
    df_lagged_inflation[f"inflation_lag{lag}"] = df_lagged_inflation[colname].shift(lag)
    
# Tilføj rullende gennemsnit (fx over de seneste 3 måneder)
#df_lagged_inflation["inflation_rolling_mean3"] = df_inflation[colname].rolling(window=3).mean()

# Fjern rækker med NaN (de første pga. lags)

df_lagged_inflation = df_lagged_inflation.dropna()
# Fjern target-kolonnen
df_lagged_inflation = df_lagged_inflation.drop(columns=["Inflation"])


# Se resultat
df_lagged_inflation
# Out:
#             inflation_lag1  inflation_lag2  inflation_lag3  inflation_lag4  \
# Date
# 2003-01-01           2.548           2.810           2.548           2.423
# 2003-02-01           2.545           2.548           2.810           2.548
# 2003-03-01           2.778           2.545           2.548           2.810
# 2003-04-01           2.886           2.778           2.545           2.548
# 2003-05-01           2.375           2.886           2.778           2.545
# ...                    ...             ...             ...             ...
# 2024-10-01           1.278           1.359           1.097           1.804
# 2024-11-01           1.614           1.278           1.359           1.097
# 2024-12-01           1.620           1.614           1.278           1.359
# 2025-01-01           1.885           1.620           1.614           1.278
# 2025-02-01           1.528           1.885           1.620           1.614
#
#             inflation_lag5  inflation_lag6  inflation_lag7  inflation_lag8  \
# Date
# 2003-01-01           2.305           2.177           2.171           2.041
# 2003-02-01           2.423           2.305           2.177           2.171
# 2003-03-01           2.548           2.423           2.305           2.177
# 2003-04-01           2.810           2.548           2.423           2.305
# 2003-05-01           2.548           2.810           2.548           2.423
# ...                    ...             ...             ...             ...
# 2024-10-01           2.155           0.765           0.938           0.766
# 2024-11-01           1.804           2.155           0.765           0.938
# 2024-12-01           1.097           1.804           2.155           0.765
# 2025-01-01           1.359           1.097           1.804           2.155
# 2025-02-01           1.278           1.359           1.097           1.804
#
#             inflation_lag9  inflation_lag10  inflation_lag11  inflation_lag12
# Date
# 2003-01-01           2.564            2.574            2.458            2.477
# 2003-02-01           2.041            2.564            2.574            2.458
# 2003-03-01           2.171            2.041            2.564            2.574
# 2003-04-01           2.177            2.171            2.041            2.564
# 2003-05-01           2.305            2.177            2.171            2.041
# ...                    ...              ...              ...              ...
# 2024-10-01           1.203            0.690            0.600            0.085
# 2024-11-01           0.766            1.203            0.690            0.600
# 2024-12-01           0.938            0.766            1.203            0.690
# 2025-01-01           0.765            0.938            0.766            1.203
# 2025-02-01           2.155            0.765            0.938            0.766
#
# [266 rows x 12 columns]

# %% [markdown]
# ## Brutto ledige

# %%
file_path = 'ledige.xlsx'
antal_ledige = pd.read_excel(file_path, header=0, decimal=",")

antal_ledige = standardize_dates(antal_ledige, "date")
df_antal_ledige = antal_ledige.resample("MS").ffill()
df_antal_ledige
# Out:
#             Bruttoledige  Ledige dagpengemodtagere  \
# Date
# 2007-01-01      119018.0                   90915.5
# 2007-02-01      115165.1                   87461.5
# 2007-03-01      110045.9                   83156.5
# 2007-04-01      108612.7                   82269.8
# 2007-05-01      105135.8                   79468.4
# ...                  ...                       ...
# 2024-10-01       88010.4                   75429.7
# 2024-11-01       88116.1                   75548.4
# 2024-12-01       87942.8                   75474.8
# 2025-01-01       87034.0                   74740.8
# 2025-02-01       87583.4                   75509.1
#
#             Ledige kontanthjælpsmodtagere
# Date
# 2007-01-01                        28102.5
# 2007-02-01                        27703.5
# 2007-03-01                        26889.5
# 2007-04-01                        26343.1
# 2007-05-01                        25667.4
# ...                                   ...
# 2024-10-01                        12580.7
# 2024-11-01                        12567.7
# 2024-12-01                        12468.0
# 2025-01-01                        12293.2
# 2025-02-01                        12074.3
#
# [218 rows x 3 columns]

# %% [markdown]
# ## Ledige i pct ( skal måske slettes?)

# %%
file_path = 'ledige_procent.xlsx'
ledige_procent = pd.read_excel(file_path, header=0, decimal=",")
#ledige.set_index("date", inplace=True)
ledige_procent
# Out:
#         date  Bruttoledige (i pct. af arbejdsstyrken)
# 0    2007M01                                      4.3
# 1    2007M02                                      4.1
# 2    2007M03                                      3.9
# 3    2007M04                                      3.9
# 4    2007M05                                      3.8
# ..       ...                                      ...
# 213  2024M10                                      2.9
# 214  2024M11                                      2.9
# 215  2024M12                                      2.9
# 216  2025M01                                      2.9
# 217  2025M02                                      2.9
#
# [218 rows x 2 columns]

# %%
df_ledige_procent = standardize_dates(ledige_procent, "date")

df_ledige_procent = df_ledige_procent.resample("MS").ffill()
df_ledige_procent
# Out:
#             Bruttoledige (i pct. af arbejdsstyrken)
# Date
# 2007-01-01                                      4.3
# 2007-02-01                                      4.1
# 2007-03-01                                      3.9
# 2007-04-01                                      3.9
# 2007-05-01                                      3.8
# ...                                             ...
# 2024-10-01                                      2.9
# 2024-11-01                                      2.9
# 2024-12-01                                      2.9
# 2025-01-01                                      2.9
# 2025-02-01                                      2.9
#
# [218 rows x 1 columns]

# %% [markdown]
# ## Antal af fødte børn

# %%
file_path = 'fødte_børn.csv'

# %%
børn = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0)

børn = standardize_dates(børn, "year")

df_børn = børn.resample("MS").ffill()
df_børn.shape
# Out:
# (277, 2)

# %%
# Tilføj rækker frem til 2025-02-01
future_index = pd.date_range(start=df_børn.index.min(), end="2025-02-01", freq="MS")

# Reindex og ffill for at fylde manglende data
df_børn = df_børn.reindex(future_index).ffill()
df_børn.index.name = "Date"
df_børn
# Out:
#             F¿dte Drenge  F¿dte Piger
# Date
# 2001-01-01       33497.0      31961.0
# 2001-02-01       33497.0      31961.0
# 2001-03-01       33497.0      31961.0
# 2001-04-01       33497.0      31961.0
# 2001-05-01       33497.0      31961.0
# ...                  ...          ...
# 2024-10-01       29501.0      27578.0
# 2024-11-01       29501.0      27578.0
# 2024-12-01       29501.0      27578.0
# 2025-01-01       29501.0      27578.0
# 2025-02-01       29501.0      27578.0
#
# [290 rows x 2 columns]

# %% [markdown]
# ## Econ indikator

# %%
file_path = 'econ_indikator.xlsx'
econ_indikator = pd.read_excel(file_path, header=0, decimal=",")
econ_indikator
# Out:
#       date  B.1*g Bruttonationalprodukt, BNP  \
# 0   2001K1                             337.7
# 1   2001K2                             340.8
# 2   2001K3                             344.9
# 3   2001K4                             348.9
# 4   2002K1                             348.7
# ..     ...                               ...
# 91  2023K4                             699.2
# 92  2024K1                             711.3
# 93  2024K2                             723.1
# 94  2024K3                             748.6
# 95  2024K4                             769.2
#
#     P.7 Import af varer og tjenester  P.71 Import af varer  \
# 0                              131.1                  88.8
# 1                              135.3                  91.5
# 2                              131.3                  89.5
# 3                              129.7                  88.7
# 4                              138.4                  91.9
# ..                               ...                   ...
# 91                             424.2                 228.7
# 92                             420.9                 228.7
# 93                             429.0                 229.4
# 94                             430.6                 231.6
# 95                             438.8                 236.8
#
#     P.72 Import af tjenester  Forsyning i alt  \
# 0                       42.3            468.8
# 1                       43.8            476.2
# 2                       41.8            476.2
# 3                       41.0            478.6
# 4                       46.6            487.1
# ..                       ...              ...
# 91                     195.5           1123.5
# 92                     192.2           1132.2
# 93                     199.6           1152.1
# 94                     198.9           1179.2
# 95                     202.0           1208.0
#
#     P.6 Eksport af varer og tjenester  P.61 Eksport af varer  \
# 0                               159.1                  104.4
# 1                               158.7                  104.0
# 2                               154.2                  103.7
# 3                               153.3                  102.5
# 4                               160.4                  106.0
# ..                                ...                    ...
# 91                              481.9                  280.8
# 92                              484.2                  280.4
# 93                              502.3                  287.0
# 94                              524.4                  299.7
# 95                              552.2                  322.5
#
#     P.62 Eksport af tjenester  P.31 Privatforbrug  ...  \
# 0                        54.7               158.2  ...
# 1                        54.7               161.5  ...
# 2                        50.5               161.8  ...
# 3                        50.8               160.6  ...
# 4                        54.3               163.8  ...
# ..                        ...                 ...  ...
# 91                      201.1               328.9  ...
# 92                      203.8               330.0  ...
# 93                      215.2               331.6  ...
# 94                      224.7               332.8  ...
# 95                      229.7               337.2  ...
#
#     N.112 Andre bygninger og anlæg  N.113-N.115 Maskiner, transportmidler mv.  \
# 0                             18.2                                       25.9
# 1                             18.6                                       27.7
# 2                             19.3                                       26.0
# 3                             19.5                                       27.4
# 4                             18.5                                       28.0
# ..                             ...                                        ...
# 91                            39.4                                       28.6
# 92                            40.4                                       32.2
# 93                            41.6                                       33.6
# 94                            42.8                                       33.7
# 95                            42.8                                       33.6
#
#     N.117 Intellektuelle rettigheder  P.52+P.53 Lagerforøgelser mv.  \
# 0                               12.0                            0.6
# 1                               12.7                           -0.7
# 2                               12.8                            3.5
# 3                               13.4                            3.2
# 4                               12.9                            1.5
# ..                               ...                            ...
# 91                              43.6                            1.1
# 92                              43.6                           -7.4
# 93                              44.1                           -3.1
# 94                              44.8                           -3.9
# 95                              45.8                          -17.9
#
#     P.52 Lagerforøgelser  \
# 0                    0.2
# 1                   -1.2
# 2                    3.0
# 3                    2.8
# 4                    1.0
# ..                   ...
# 91                   0.1
# 92                  -8.5
# 93                  -4.1
# 94                  -4.9
# 95                 -18.8
#
#     P.53 Anskaffelser minus afhændelser af værdigenstande  \
# 0                                                 0.4
# 1                                                 0.5
# 2                                                 0.5
# 3                                                 0.4
# 4                                                 0.6
# ..                                                ...
# 91                                                1.0
# 92                                                1.0
# 93                                                1.0
# 94                                                1.0
# 95                                                0.9
#
#     Endelig indenlandsk anvendelse  Endelig anvendelse i alt  \
# 0                            310.2                     469.3
# 1                            316.9                     475.6
# 2                            322.5                     476.7
# 3                            324.8                     478.1
# 4                            325.8                     486.2
# ..                             ...                       ...
# 91                           640.1                    1121.9
# 92                           640.0                    1124.2
# 93                           653.9                    1156.2
# 94                           660.1                    1184.5
# 95                           654.5                    1206.7
#
#     Samlede præsterede timer (mio. timer)  \
# 0                                  1024.7
# 1                                  1029.1
# 2                                  1018.4
# 3                                  1014.4
# 4                                  1012.5
# ..                                    ...
# 91                                 1107.3
# 92                                 1116.6
# 93                                 1108.6
# 94                                 1109.6
# 95                                 1114.5
#
#     Samlet antal beskæftigede (1000 personer)
# 0                                      2781.6
# 1                                      2786.8
# 2                                      2777.8
# 3                                      2783.7
# 4                                      2780.9
# ..                                        ...
# 91                                     3210.1
# 92                                     3221.9
# 93                                     3225.3
# 94                                     3228.5
# 95                                     3240.3
#
# [96 rows x 32 columns]

# %%
econ_indikator = standardize_dates(econ_indikator, "date")

# %%
df_econ_indikator = econ_indikator.resample("MS").ffill()
df_econ_indikator.shape
# Out:
# (286, 31)

# %%
# Tilføj rækker frem til 2025-02-01
future_index = pd.date_range(start=df_econ_indikator.index.min(), end="2025-02-01", freq="MS")

# Reindex og ffill for at fylde manglende data
df_econ_indikator = df_econ_indikator.reindex(future_index).ffill()
df_econ_indikator.index.name = "Date"
df_econ_indikator
# Out:
#             B.1*g Bruttonationalprodukt, BNP  \
# Date
# 2001-01-01                             337.7
# 2001-02-01                             337.7
# 2001-03-01                             337.7
# 2001-04-01                             340.8
# 2001-05-01                             340.8
# ...                                      ...
# 2024-10-01                             769.2
# 2024-11-01                             769.2
# 2024-12-01                             769.2
# 2025-01-01                             769.2
# 2025-02-01                             769.2
#
#             P.7 Import af varer og tjenester  P.71 Import af varer  \
# Date
# 2001-01-01                             131.1                  88.8
# 2001-02-01                             131.1                  88.8
# 2001-03-01                             131.1                  88.8
# 2001-04-01                             135.3                  91.5
# 2001-05-01                             135.3                  91.5
# ...                                      ...                   ...
# 2024-10-01                             438.8                 236.8
# 2024-11-01                             438.8                 236.8
# 2024-12-01                             438.8                 236.8
# 2025-01-01                             438.8                 236.8
# 2025-02-01                             438.8                 236.8
#
#             P.72 Import af tjenester  Forsyning i alt  \
# Date
# 2001-01-01                      42.3            468.8
# 2001-02-01                      42.3            468.8
# 2001-03-01                      42.3            468.8
# 2001-04-01                      43.8            476.2
# 2001-05-01                      43.8            476.2
# ...                              ...              ...
# 2024-10-01                     202.0           1208.0
# 2024-11-01                     202.0           1208.0
# 2024-12-01                     202.0           1208.0
# 2025-01-01                     202.0           1208.0
# 2025-02-01                     202.0           1208.0
#
#             P.6 Eksport af varer og tjenester  P.61 Eksport af varer  \
# Date
# 2001-01-01                              159.1                  104.4
# 2001-02-01                              159.1                  104.4
# 2001-03-01                              159.1                  104.4
# 2001-04-01                              158.7                  104.0
# 2001-05-01                              158.7                  104.0
# ...                                       ...                    ...
# 2024-10-01                              552.2                  322.5
# 2024-11-01                              552.2                  322.5
# 2024-12-01                              552.2                  322.5
# 2025-01-01                              552.2                  322.5
# 2025-02-01                              552.2                  322.5
#
#             P.62 Eksport af tjenester  P.31 Privatforbrug  \
# Date
# 2001-01-01                       54.7               158.2
# 2001-02-01                       54.7               158.2
# 2001-03-01                       54.7               158.2
# 2001-04-01                       54.7               161.5
# 2001-05-01                       54.7               161.5
# ...                               ...                 ...
# 2024-10-01                      229.7               337.2
# 2024-11-01                      229.7               337.2
# 2024-12-01                      229.7               337.2
# 2025-01-01                      229.7               337.2
# 2025-02-01                      229.7               337.2
#
#             P.31 Husholdningernes forbrugsudgifter  ...  \
# Date                                                ...
# 2001-01-01                                   152.9  ...
# 2001-02-01                                   152.9  ...
# 2001-03-01                                   152.9  ...
# 2001-04-01                                   156.2  ...
# 2001-05-01                                   156.2  ...
# ...                                            ...  ...
# 2024-10-01                                   325.9  ...
# 2024-11-01                                   325.9  ...
# 2024-12-01                                   325.9  ...
# 2025-01-01                                   325.9  ...
# 2025-02-01                                   325.9  ...
#
#             N.112 Andre bygninger og anlæg  \
# Date
# 2001-01-01                            18.2
# 2001-02-01                            18.2
# 2001-03-01                            18.2
# 2001-04-01                            18.6
# 2001-05-01                            18.6
# ...                                    ...
# 2024-10-01                            42.8
# 2024-11-01                            42.8
# 2024-12-01                            42.8
# 2025-01-01                            42.8
# 2025-02-01                            42.8
#
#             N.113-N.115 Maskiner, transportmidler mv.  \
# Date
# 2001-01-01                                       25.9
# 2001-02-01                                       25.9
# 2001-03-01                                       25.9
# 2001-04-01                                       27.7
# 2001-05-01                                       27.7
# ...                                               ...
# 2024-10-01                                       33.6
# 2024-11-01                                       33.6
# 2024-12-01                                       33.6
# 2025-01-01                                       33.6
# 2025-02-01                                       33.6
#
#             N.117 Intellektuelle rettigheder  P.52+P.53 Lagerforøgelser mv.  \
# Date
# 2001-01-01                              12.0                            0.6
# 2001-02-01                              12.0                            0.6
# 2001-03-01                              12.0                            0.6
# 2001-04-01                              12.7                           -0.7
# 2001-05-01                              12.7                           -0.7
# ...                                      ...                            ...
# 2024-10-01                              45.8                          -17.9
# 2024-11-01                              45.8                          -17.9
# 2024-12-01                              45.8                          -17.9
# 2025-01-01                              45.8                          -17.9
# 2025-02-01                              45.8                          -17.9
#
#             P.52 Lagerforøgelser  \
# Date
# 2001-01-01                   0.2
# 2001-02-01                   0.2
# 2001-03-01                   0.2
# 2001-04-01                  -1.2
# 2001-05-01                  -1.2
# ...                          ...
# 2024-10-01                 -18.8
# 2024-11-01                 -18.8
# 2024-12-01                 -18.8
# 2025-01-01                 -18.8
# 2025-02-01                 -18.8
#
#             P.53 Anskaffelser minus afhændelser af værdigenstande  \
# Date
# 2001-01-01                                                0.4
# 2001-02-01                                                0.4
# 2001-03-01                                                0.4
# 2001-04-01                                                0.5
# 2001-05-01                                                0.5
# ...                                                       ...
# 2024-10-01                                                0.9
# 2024-11-01                                                0.9
# 2024-12-01                                                0.9
# 2025-01-01                                                0.9
# 2025-02-01                                                0.9
#
#             Endelig indenlandsk anvendelse  Endelig anvendelse i alt  \
# Date
# 2001-01-01                           310.2                     469.3
# 2001-02-01                           310.2                     469.3
# 2001-03-01                           310.2                     469.3
# 2001-04-01                           316.9                     475.6
# 2001-05-01                           316.9                     475.6
# ...                                    ...                       ...
# 2024-10-01                           654.5                    1206.7
# 2024-11-01                           654.5                    1206.7
# 2024-12-01                           654.5                    1206.7
# 2025-01-01                           654.5                    1206.7
# 2025-02-01                           654.5                    1206.7
#
#             Samlede præsterede timer (mio. timer)  \
# Date
# 2001-01-01                                 1024.7
# 2001-02-01                                 1024.7
# 2001-03-01                                 1024.7
# 2001-04-01                                 1029.1
# 2001-05-01                                 1029.1
# ...                                           ...
# 2024-10-01                                 1114.5
# 2024-11-01                                 1114.5
# 2024-12-01                                 1114.5
# 2025-01-01                                 1114.5
# 2025-02-01                                 1114.5
#
#             Samlet antal beskæftigede (1000 personer)
# Date
# 2001-01-01                                     2781.6
# 2001-02-01                                     2781.6
# 2001-03-01                                     2781.6
# 2001-04-01                                     2786.8
# 2001-05-01                                     2786.8
# ...                                               ...
# 2024-10-01                                     3240.3
# 2024-11-01                                     3240.3
# 2024-12-01                                     3240.3
# 2025-01-01                                     3240.3
# 2025-02-01                                     3240.3
#
# [290 rows x 31 columns]

# %% [markdown]
# ### Valutakurser

# %%
file_path = 'valutakurser.xlsx'

# %%
Valutakurser = pd.read_excel(file_path, header=0, decimal=",")

# %%
Valutakurser = standardize_dates(Valutakurser, "date")

# %%
df_valutakurser = Valutakurser.resample("MS").ffill()
df_valutakurser
# Out:
#             EUR Euro  (Jan. 1999-)  USD Amerikanske dollar  (Jan. 1979-)  \
# Date
# 2001-01-01                746.4373                              795.0623
# 2001-02-01                746.3120                              809.4930
# 2001-03-01                746.4391                              820.6772
# 2001-04-01                746.3239                              835.9222
# 2001-05-01                746.1628                              852.5195
# ...                            ...                                   ...
# 2024-10-01                745.9265                              684.1126
# 2024-11-01                745.8276                              701.7319
# 2024-12-01                745.8878                              711.1756
# 2025-01-01                746.0895                              720.6409
# 2025-02-01                745.9200                              716.3965
#
#             GBP Britiske pund  (Jan. 1981-)  SEK Svenske kroner  (Jan. 1980-)
# Date
# 2001-01-01                        1175.5700                           83.8845
# 2001-02-01                        1176.8350                           83.1745
# 2001-03-01                        1186.0940                           81.7718
# 2001-04-01                        1199.7760                           81.8889
# 2001-05-01                        1215.6630                           82.3338
# ...                                     ...                               ...
# 2024-10-01                         893.3804                           65.4065
# 2024-11-01                         894.5195                           64.3914
# 2024-12-01                         900.8617                           64.8328
# 2025-01-01                         889.2100                           64.9918
# 2025-02-01                         897.9405                           66.3225
#
# [290 rows x 4 columns]

# %% [markdown]
# ### Transaktioner med kort

# %%
file_path = 'transaktioner_medkort.xlsx'
transaktioner_medkort = pd.read_excel(file_path, header=0, decimal=",")
transaktioner_medkort.shape
# Out:
# (2253, 3)

# %%
transaktioner_medkort = standardize_dates(transaktioner_medkort, "date")

# %%
df_transaktioner_medkort = transaktioner_medkort.resample("MS").ffill()
df_transaktioner_medkort
# Out:
#             Transaktioner - Værdi (kr.)  Antal transaktioner med kort (stk.)
# Date
# 2019-01-01                    532818728                              2324456
# 2019-02-01                   1876394477                              6817359
# 2019-03-01                   1954701700                              7097706
# 2019-04-01                   1563414384                              5740496
# 2019-05-01                   1805399506                              6516506
# ...                                 ...                                  ...
# 2024-11-01                   2538732203                              9204718
# 2024-12-01                   2226184670                              8256522
# 2025-01-01                   1112985682                              4235434
# 2025-02-01                   2128014674                              8201853
# 2025-03-01                   2136274605                              8309405
#
# [75 rows x 2 columns]

# %% [markdown]
# ### antal_ejendomsalg

# %%
file_path = 'ejdendom_antalsalg.xlsx'
ejendomsalg = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
ejendomsalg = standardize_dates(ejendomsalg, "date")

# %%
df_ejendomsalg = ejendomsalg.resample("MS").ffill()
df_ejendomsalg
# Out:
#             Total salg af Enfamiliehuse  Total salg af Sommerhuse  \
# Date
# 2005-01-01                        14398                      2915
# 2005-02-01                        14398                      2915
# 2005-03-01                        14398                      2915
# 2005-04-01                        15155                      3141
# 2005-05-01                        15155                      3141
# ...                                 ...                       ...
# 2024-03-01                        11822                      1995
# 2024-04-01                        12834                      2140
# 2024-05-01                        12834                      2140
# 2024-06-01                        12834                      2140
# 2024-07-01                        13250                      2298
#
#             Total salg af Ejerlejligheder
# Date
# 2005-01-01                           6104
# 2005-02-01                           6104
# 2005-03-01                           6104
# 2005-04-01                           6602
# 2005-05-01                           6602
# ...                                   ...
# 2024-03-01                           3171
# 2024-04-01                           4049
# 2024-05-01                           4049
# 2024-06-01                           4049
# 2024-07-01                           4448
#
# [235 rows x 3 columns]

# %% [markdown]
# ## Medlemer af Folkekirken

# %%
file_path = 'medlemer_folkekirken.csv'
folkekirken_medlemmer = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0)

# Kør standardiseringsfunktionen
folkekirken_medlemmer = standardize_dates(folkekirken_medlemmer, "date")

# %%
df_folkekirken_medlemmer= folkekirken_medlemmer.resample("MS").ffill()
df_folkekirken_medlemmer
# Out:
#             Medlemmer af Folkekirken
# Date
# 2007-01-01                   4499343
# 2007-02-01                   4499343
# 2007-03-01                   4499343
# 2007-04-01                   4496926
# 2007-05-01                   4496926
# ...                              ...
# 2024-09-01                   4245853
# 2024-10-01                   4241820
# 2024-11-01                   4241820
# 2024-12-01                   4241820
# 2025-01-01                   4234315
#
# [217 rows x 1 columns]

# %% [markdown]
# ## Antal Totale Skilsmisser

# %%
file_path = 'total_skilsmisser.csv'
total_skilsmisser = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0)

# Kør standardiseringsfunktionen
total_skilsmisser = standardize_dates(total_skilsmisser, "date")

# %%
df_total_skilsmisser = total_skilsmisser.resample("MS").ffill()
df_total_skilsmisser
# Out:
#             Antal Skilsmisser
# Date
# 2001-01-01              14692
# 2001-02-01              14692
# 2001-03-01              14692
# 2001-04-01              14692
# 2001-05-01              14692
# ...                       ...
# 2023-09-01              12862
# 2023-10-01              12862
# 2023-11-01              12862
# 2023-12-01              12862
# 2024-01-01              12856
#
# [277 rows x 1 columns]

# %% [markdown]
# ## Vielser

# %%
file_path = 'vielser.xlsx'
vielser = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
vielser = standardize_dates(vielser, "year")

# %%
df_vielser = vielser.resample("MS").ffill()
df_vielser
# Out:
#             Gennemsnitsalder for 1. gangsviede mænd  \
# Date
# 2001-01-01                                     32.8
# 2001-02-01                                     32.8
# 2001-03-01                                     32.8
# 2001-04-01                                     32.8
# 2001-05-01                                     32.8
# ...                                             ...
# 2023-09-01                                     35.9
# 2023-10-01                                     35.9
# 2023-11-01                                     35.9
# 2023-12-01                                     35.9
# 2024-01-01                                     36.0
#
#             Gennemsnitsalder for 1. gangsviede kvinder  Vielser i alt
# Date
# 2001-01-01                                        30.3          36909
# 2001-02-01                                        30.3          36909
# 2001-03-01                                        30.3          36909
# 2001-04-01                                        30.3          36909
# 2001-05-01                                        30.3          36909
# ...                                                ...            ...
# 2023-09-01                                        33.7          31582
# 2023-10-01                                        33.7          31582
# 2023-11-01                                        33.7          31582
# 2023-12-01                                        33.7          31582
# 2024-01-01                                        33.9          32861
#
# [277 rows x 3 columns]

# %% [markdown]
# ## total_hustande

# %%
file_path = 'total_hustande.csv'
total_hustande = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0)

# Kør standardiseringsfunktionen
total_hustande = standardize_dates(total_hustande, "year")

# %%
df_total_hustande = total_hustande.resample("MS").ffill()
df_total_hustande
# Out:
#             Hustande, Hele landet
# Date
# 2001-01-01                2448490
# 2001-02-01                2448490
# 2001-03-01                2448490
# 2001-04-01                2448490
# 2001-05-01                2448490
# ...                           ...
# 2024-09-01                2834240
# 2024-10-01                2834240
# 2024-11-01                2834240
# 2024-12-01                2834240
# 2025-01-01                2857302
#
# [289 rows x 1 columns]

# %% [markdown]
# ## Fertilitetskvotienter

# %%
file_path = 'Fertilitetskvotienter.xlsx'
Fertilitetskvotienter = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
Fertilitetskvotienter = standardize_dates(Fertilitetskvotienter, "year")

# %%
df_fertilitetskvotienter = Fertilitetskvotienter.resample("MS").ffill()
df_fertilitetskvotienter
# Out:
#             Samlet fertilitet
# Date
# 2001-01-01             1745.0
# 2001-02-01             1745.0
# 2001-03-01             1745.0
# 2001-04-01             1745.0
# 2001-05-01             1745.0
# ...                       ...
# 2023-09-01             1495.9
# 2023-10-01             1495.9
# 2023-11-01             1495.9
# 2023-12-01             1495.9
# 2024-01-01             1465.6
#
# [277 rows x 1 columns]

# %% [markdown]
# ## Implicit Lønindeks

# %%
file_path = 'Implicit_lønindeks.xlsx'
implicit_lønindeks = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
implicit_lønindeks = standardize_dates(implicit_lønindeks, "date")

# %%
df_implicit_lønindeks = implicit_lønindeks.resample("MS").ffill()
df_implicit_lønindeks = df_implicit_lønindeks.add_prefix("Implicit_lønindeks_")

# %%
df_implicit_lønindeks
# Out:
#             Implicit_lønindeks_Forskning og udvikling  \
# Date
# 2005-01-01                                      100.0
# 2005-02-01                                      100.0
# 2005-03-01                                      100.0
# 2005-04-01                                      103.9
# 2005-05-01                                      103.9
# ...                                               ...
# 2024-06-01                                      158.5
# 2024-07-01                                      159.3
# 2024-08-01                                      159.3
# 2024-09-01                                      159.3
# 2024-10-01                                      158.8
#
#             Implicit_lønindeks_P Undervisning  \
# Date
# 2005-01-01                              100.0
# 2005-02-01                              100.0
# 2005-03-01                              100.0
# 2005-04-01                              103.3
# 2005-05-01                              103.3
# ...                                       ...
# 2024-06-01                              162.1
# 2024-07-01                              162.4
# 2024-08-01                              162.4
# 2024-09-01                              162.4
# 2024-10-01                              162.2
#
#             Implicit_lønindeks_R Kultur og fritid  \
# Date
# 2005-01-01                                  100.0
# 2005-02-01                                  100.0
# 2005-03-01                                  100.0
# 2005-04-01                                  102.1
# 2005-05-01                                  102.1
# ...                                           ...
# 2024-06-01                                  159.6
# 2024-07-01                                  161.1
# 2024-08-01                                  161.1
# 2024-09-01                                  161.1
# 2024-10-01                                  161.7
#
#             Implicit_lønindeks_2 Industri, råstofindvinding og forsyningsvirksomhed  \
# Date
# 2005-01-01                                              100.0
# 2005-02-01                                              100.0
# 2005-03-01                                              100.0
# 2005-04-01                                              100.4
# 2005-05-01                                              100.4
# ...                                                       ...
# 2024-06-01                                              167.1
# 2024-07-01                                              167.0
# 2024-08-01                                              167.0
# 2024-09-01                                              167.0
# 2024-10-01                                              167.9
#
#             Implicit_lønindeks_3 Bygge og anlæg  \
# Date
# 2005-01-01                                100.0
# 2005-02-01                                100.0
# 2005-03-01                                100.0
# 2005-04-01                                100.2
# 2005-05-01                                100.2
# ...                                         ...
# 2024-06-01                                159.9
# 2024-07-01                                158.9
# 2024-08-01                                158.9
# 2024-09-01                                158.9
# 2024-10-01                                158.8
#
#             Implicit_lønindeks_4 Handel og transport mv.  \
# Date
# 2005-01-01                                         100.0
# 2005-02-01                                         100.0
# 2005-03-01                                         100.0
# 2005-04-01                                         100.6
# 2005-05-01                                         100.6
# ...                                                  ...
# 2024-06-01                                         154.0
# 2024-07-01                                         154.1
# 2024-08-01                                         154.1
# 2024-09-01                                         154.1
# 2024-10-01                                         154.8
#
#             Implicit_lønindeks_5 Information og kommunikation  \
# Date
# 2005-01-01                                              100.0
# 2005-02-01                                              100.0
# 2005-03-01                                              100.0
# 2005-04-01                                              100.7
# 2005-05-01                                              100.7
# ...                                                       ...
# 2024-06-01                                              159.3
# 2024-07-01                                              160.3
# 2024-08-01                                              160.3
# 2024-09-01                                              160.3
# 2024-10-01                                              161.3
#
#             Implicit_lønindeks_6 Finansiering og forsikring  \
# Date
# 2005-01-01                                            100.0
# 2005-02-01                                            100.0
# 2005-03-01                                            100.0
# 2005-04-01                                            100.7
# 2005-05-01                                            100.7
# ...                                                     ...
# 2024-06-01                                            173.2
# 2024-07-01                                            174.8
# 2024-08-01                                            174.8
# 2024-09-01                                            174.8
# 2024-10-01                                            176.0
#
#             Implicit_lønindeks_7 Ejendomshandel og udlejning  \
# Date
# 2005-01-01                                             100.0
# 2005-02-01                                             100.0
# 2005-03-01                                             100.0
# 2005-04-01                                             100.6
# 2005-05-01                                             100.6
# ...                                                      ...
# 2024-06-01                                             157.6
# 2024-07-01                                             158.0
# 2024-08-01                                             158.0
# 2024-09-01                                             158.0
# 2024-10-01                                             159.0
#
#             Implicit_lønindeks_8 Erhvervsservice  \
# Date
# 2005-01-01                                 100.0
# 2005-02-01                                 100.0
# 2005-03-01                                 100.0
# 2005-04-01                                 100.4
# 2005-05-01                                 100.4
# ...                                          ...
# 2024-06-01                                 161.0
# 2024-07-01                                 162.5
# 2024-08-01                                 162.5
# 2024-09-01                                 162.5
# 2024-10-01                                 163.4
#
#             Implicit_lønindeks_10 Kultur, fritid og anden service
# Date
# 2005-01-01                                              100.0
# 2005-02-01                                              100.0
# 2005-03-01                                              100.0
# 2005-04-01                                              100.6
# 2005-05-01                                              100.6
# ...                                                       ...
# 2024-06-01                                              140.5
# 2024-07-01                                              141.1
# 2024-08-01                                              141.1
# 2024-09-01                                              141.1
# 2024-10-01                                              141.9
#
# [238 rows x 11 columns]

# %% [markdown]
# ## antal_beskæftigede

# %%
file_path = 'antal_beskæftigede.xlsx'
antal_beskæftigede = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
antal_beskæftigede = standardize_dates(antal_beskæftigede, "year")

# %%
df_antal_beskæftigede = antal_beskæftigede.resample("MS").ffill()
df_antal_beskæftigede  # Se de første 12 måneder
# Out:
#             Beskæftigede Mænd  Beskæftigede Kvinder
# Date
# 2008-01-01            1493769               1351045
# 2008-02-01            1493769               1351045
# 2008-03-01            1493769               1351045
# 2008-04-01            1493769               1351045
# 2008-05-01            1493769               1351045
# ...                       ...                   ...
# 2022-09-01            1618463               1471748
# 2022-10-01            1618463               1471748
# 2022-11-01            1618463               1471748
# 2022-12-01            1618463               1471748
# 2023-01-01            1629953               1482509
#
# [181 rows x 2 columns]

# %% [markdown]
# ## Forbrugerforventninger

# %%
file_path = 'Forbrugerforventninger.xlsx'
Forbrugerforventninger = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
Forbrugerforventninger = standardize_dates(Forbrugerforventninger, "date")

# %%
df_forbrugerforventninger = Forbrugerforventninger.resample("MS").ffill()
df_forbrugerforventninger  # Se de første 12 måneder
# Out:
#             Forbrugertillidsindikatoren  \
# Date
# 2001-01-01                          3.0
# 2001-02-01                          1.0
# 2001-03-01                          0.0
# 2001-04-01                         -2.0
# 2001-05-01                          0.0
# ...                                 ...
# 2024-10-01                         -8.9
# 2024-11-01                         -9.3
# 2024-12-01                        -13.1
# 2025-01-01                        -11.7
# 2025-02-01                        -14.5
#
#             Familiens økonomiske situation i dag, sammenlignet med for et år siden  \
# Date
# 2001-01-01                                                7.0
# 2001-02-01                                                3.0
# 2001-03-01                                                3.0
# 2001-04-01                                                4.0
# 2001-05-01                                                8.0
# ...                                                       ...
# 2024-10-01                                               -8.9
# 2024-11-01                                              -10.1
# 2024-12-01                                              -11.2
# 2025-01-01                                               -5.3
# 2025-02-01                                               -5.2
#
#             Familiens økonomiske  situation om et år, sammenlignet med i dag  \
# Date
# 2001-01-01                                               13.0
# 2001-02-01                                               17.0
# 2001-03-01                                               13.0
# 2001-04-01                                               14.0
# 2001-05-01                                               12.0
# ...                                                       ...
# 2024-10-01                                               -1.0
# 2024-11-01                                                0.0
# 2024-12-01                                               -1.2
# 2025-01-01                                               -1.0
# 2025-02-01                                               -4.8
#
#             Danmarks økonomiske situation i dag, sammenlignet med for et år siden  \
# Date
# 2001-01-01                                                3.0
# 2001-02-01                                                0.0
# 2001-03-01                                               -3.0
# 2001-04-01                                               -9.0
# 2001-05-01                                               -5.0
# ...                                                       ...
# 2024-10-01                                               -9.8
# 2024-11-01                                              -12.5
# 2024-12-01                                              -17.2
# 2025-01-01                                              -15.9
# 2025-02-01                                              -20.6
#
#             Danmarks økonomiske situation om et år, sammenlignet med i dag  \
# Date
# 2001-01-01                                               -3.0
# 2001-02-01                                               -4.0
# 2001-03-01                                               -8.0
# 2001-04-01                                               -9.0
# 2001-05-01                                               -6.0
# ...                                                       ...
# 2024-10-01                                               -8.5
# 2024-11-01                                              -10.9
# 2024-12-01                                              -18.0
# 2025-01-01                                              -18.6
# 2025-02-01                                              -29.3
#
#             Anskaffelse af større forbrugsgoder, fordelagtigt for øjeblikket  \
# Date
# 2001-01-01                                               -3.0
# 2001-02-01                                               -9.0
# 2001-03-01                                               -6.0
# 2001-04-01                                              -10.0
# 2001-05-01                                               -9.0
# ...                                                       ...
# 2024-10-01                                              -16.1
# 2024-11-01                                              -13.1
# 2024-12-01                                              -18.0
# 2025-01-01                                              -17.8
# 2025-02-01                                              -12.6
#
#             Priser i dag, sammenlignet med for et år siden  \
# Date
# 2001-01-01                                           -13.0
# 2001-02-01                                           -12.0
# 2001-03-01                                           -15.0
# 2001-04-01                                           -14.0
# 2001-05-01                                            -7.0
# ...                                                    ...
# 2024-10-01                                            28.0
# 2024-11-01                                            27.4
# 2024-12-01                                            31.6
# 2025-01-01                                            32.8
# 2025-02-01                                            33.3
#
#             Priser om et år, sammenlignet med i dag  \
# Date
# 2001-01-01                                    -12.0
# 2001-02-01                                    -11.0
# 2001-03-01                                    -10.0
# 2001-04-01                                    -11.0
# 2001-05-01                                     -7.0
# ...                                             ...
# 2024-10-01                                     21.0
# 2024-11-01                                     23.2
# 2024-12-01                                     29.6
# 2025-01-01                                     29.2
# 2025-02-01                                     37.0
#
#             Arbejdsløsheden om et år, sammenlignet med i dag  \
# Date
# 2001-01-01                                               0.0
# 2001-02-01                                              -2.0
# 2001-03-01                                               1.0
# 2001-04-01                                               5.0
# 2001-05-01                                               3.0
# ...                                                      ...
# 2024-10-01                                              10.2
# 2024-11-01                                              13.7
# 2024-12-01                                              13.0
# 2025-01-01                                              10.1
# 2025-02-01                                              16.2
#
#             Anskaffelse af større forbrugsgoder, inden for de næste 12 mdr.  \
# Date
# 2001-01-01                                               -7.0
# 2001-02-01                                               -6.0
# 2001-03-01                                               -9.0
# 2001-04-01                                               -6.0
# 2001-05-01                                               -6.0
# ...                                                       ...
# 2024-10-01                                               -8.0
# 2024-11-01                                               -3.7
# 2024-12-01                                               -7.5
# 2025-01-01                                               -7.0
# 2025-02-01                                               -6.2
#
#             Anser det som fornuftigt at spare op i den nuværende økonomiske situation  \
# Date
# 2001-01-01                                               69.0
# 2001-02-01                                               74.0
# 2001-03-01                                               76.0
# 2001-04-01                                               72.0
# 2001-05-01                                               73.0
# ...                                                       ...
# 2024-10-01                                               65.3
# 2024-11-01                                               67.2
# 2024-12-01                                               65.0
# 2025-01-01                                               62.4
# 2025-02-01                                               66.5
#
#             Regner med at kunne spare op i de kommende 12 måneder  \
# Date
# 2001-01-01                                               25.0
# 2001-02-01                                               26.0
# 2001-03-01                                               32.0
# 2001-04-01                                               23.0
# 2001-05-01                                               30.0
# ...                                                       ...
# 2024-10-01                                               26.1
# 2024-11-01                                               30.1
# 2024-12-01                                               26.8
# 2025-01-01                                               23.8
# 2025-02-01                                               30.0
#
#             Familiens økonomiske situation lige nu: kan spare/penge slår til/ bruger mere end man tjener
# Date
# 2001-01-01                                               25.0
# 2001-02-01                                               22.0
# 2001-03-01                                               27.0
# 2001-04-01                                               24.0
# 2001-05-01                                               27.0
# ...                                                       ...
# 2024-10-01                                               26.9
# 2024-11-01                                               25.3
# 2024-12-01                                               24.0
# 2025-01-01                                               26.3
# 2025-02-01                                               29.1
#
# [290 rows x 13 columns]

# %% [markdown]
# ## Befolkningens udvikling

# %%
file_path = 'befolkningens_udvikling.xlsx'
befolkningens_udvikling = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
befolkningens_udvikling = standardize_dates(befolkningens_udvikling, "date")

# %%
df_befolkningens_udvikling = befolkningens_udvikling.resample("MS").ffill()
df_befolkningens_udvikling  # Se de første 12 måneder
# Out:
#             Befolkningen ultimo forrige kvartal  Levendefødte   Døde  \
# Date
# 2007-04-01                              5451995         15867  13579
# 2007-05-01                              5451995         15867  13579
# 2007-06-01                              5451995         15867  13579
# 2007-07-01                              5457422         17177  13037
# 2007-08-01                              5457422         17177  13037
# ...                                         ...           ...    ...
# 2024-06-01                              5967824         14351  13580
# 2024-07-01                              5972420         14942  13701
# 2024-08-01                              5972420         14942  13701
# 2024-09-01                              5972420         14942  13701
# 2024-10-01                              5989985         13978  14682
#
#             Fødselsoverskud  Tilflyttede  Fraflyttede  Nettotilflyttede  \
# Date
# 2007-04-01             2288        61780        61780                 0
# 2007-05-01             2288        61780        61780                 0
# 2007-06-01             2288        61780        61780                 0
# 2007-07-01             4140        92588        92588                 0
# 2007-08-01             4140        92588        92588                 0
# ...                     ...          ...          ...               ...
# 2024-06-01              771        71563        71563                 0
# 2024-07-01             1241       100951       100951                 0
# 2024-08-01             1241       100951       100951                 0
# 2024-09-01             1241       100951       100951                 0
# 2024-10-01             -704        73454        73454                 0
#
#             Indvandrede i alt  Indvandret i indeværende kvartal  \
# Date
# 2007-04-01              12722                             12178
# 2007-05-01              12722                             12178
# 2007-06-01              12722                             12178
# 2007-07-01              24161                             23384
# 2007-08-01              24161                             23384
# ...                       ...                               ...
# 2024-06-01              19464                             18235
# 2024-07-01              37612                             35622
# 2024-08-01              37612                             35622
# 2024-09-01              37612                             35622
# 2024-10-01              20943                             18578
#
#             Indvandret før indeværende kvartal  Udvandrede i alt  \
# Date
# 2007-04-01                                 544              9330
# 2007-05-01                                 544              9330
# 2007-06-01                                 544              9330
# 2007-07-01                                 777             14099
# 2007-08-01                                 777             14099
# ...                                        ...               ...
# 2024-06-01                                1229             15394
# 2024-07-01                                1990             21049
# 2024-08-01                                1990             21049
# 2024-09-01                                1990             21049
# 2024-10-01                                2365             17261
#
#             Udvandret i indeværende kvartal  \
# Date
# 2007-04-01                             9330
# 2007-05-01                             9330
# 2007-06-01                             9330
# 2007-07-01                            14099
# 2007-08-01                            14099
# ...                                     ...
# 2024-06-01                            11172
# 2024-07-01                            16009
# 2024-08-01                            16009
# 2024-09-01                            16009
# 2024-10-01                            11857
#
#             Udvandret før indeværende kvartal  Nettoindvandrede  Korrektioner  \
# Date
# 2007-04-01                                  0              3392          -253
# 2007-05-01                                  0              3392          -253
# 2007-06-01                                  0              3392          -253
# 2007-07-01                                  0             10062          -715
# 2007-08-01                                  0             10062          -715
# ...                                       ...               ...           ...
# 2024-06-01                               4222              4070          -245
# 2024-07-01                               5040             16563          -239
# 2024-08-01                               5040             16563          -239
# 2024-09-01                               5040             16563          -239
# 2024-10-01                               5404              3682          -229
#
#             Befolkningstilvækst  Befolkningen ultimo indeværende kvartal
# Date
# 2007-04-01                 5427                                  5457422
# 2007-05-01                 5427                                  5457422
# 2007-06-01                 5427                                  5457422
# 2007-07-01                13487                                  5470909
# 2007-08-01                13487                                  5470909
# ...                         ...                                      ...
# 2024-06-01                 4596                                  5972420
# 2024-07-01                17565                                  5989985
# 2024-08-01                17565                                  5989985
# 2024-09-01                17565                                  5989985
# 2024-10-01                 2749                                  5992734
#
# [211 rows x 17 columns]

# %% [markdown]
# ## Antal på kontanthjælp

# %%
file_path = 'antal_kontanthjælp.xlsx'
antal_kontanthjælp = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
antal_kontanthjælp = standardize_dates(antal_kontanthjælp, "date")

df_antal_kontanthjælp = antal_kontanthjælp.resample("MS").ffill()
df_antal_kontanthjælp  # Se de første 12 måneder
# Out:
#             Kontanthjælp, I alt
# Date
# 2007-01-01               125820
# 2007-02-01               124115
# 2007-03-01               123046
# 2007-04-01               121673
# 2007-05-01               120474
# ...                         ...
# 2024-08-01                88837
# 2024-09-01                88768
# 2024-10-01                88742
# 2024-11-01                88370
# 2024-12-01                88115
#
# [216 rows x 1 columns]

# %% [markdown]
# ## Antal overtrædelse

# %%
file_path = 'antal_overtrædelse.xlsx'
antal_overtrædelse = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
antal_overtrædelse = standardize_dates(antal_overtrædelse, "date")

df_antal_overtrædelse = antal_overtrædelse.resample("MS").ffill()
df_antal_overtrædelse  # Se de første 12 måneder
# Out:
#             Overtrædelsens art i alt  Straffelov i alt  \
# Date
# 2001-01-01                    127582            111675
# 2001-02-01                    127582            111675
# 2001-03-01                    127582            111675
# 2001-04-01                    132619            116253
# 2001-05-01                    132619            116253
# ...                              ...               ...
# 2024-06-01                    116061             85050
# 2024-07-01                    112860             83807
# 2024-08-01                    112860             83807
# 2024-09-01                    112860             83807
# 2024-10-01                    110141             82013
#
#             Seksualforbrydelser i alt  Voldsforbrydelser i alt  \
# Date
# 2001-01-01                        627                     3629
# 2001-02-01                        627                     3629
# 2001-03-01                        627                     3629
# 2001-04-01                        637                     3994
# 2001-05-01                        637                     3994
# ...                               ...                      ...
# 2024-06-01                       2145                     7346
# 2024-07-01                       1938                     6945
# 2024-08-01                       1938                     6945
# 2024-09-01                       1938                     6945
# 2024-10-01                       1817                     6743
#
#             Ejendomsforbrydelser i alt  Særlove i alt
# Date
# 2001-01-01                      105565          15907
# 2001-02-01                      105565          15907
# 2001-03-01                      105565          15907
# 2001-04-01                      109886          16366
# 2001-05-01                      109886          16366
# ...                                ...            ...
# 2024-06-01                       71908          31011
# 2024-07-01                       71727          29053
# 2024-08-01                       71727          29053
# 2024-09-01                       71727          29053
# 2024-10-01                       70215          28128
#
# [286 rows x 6 columns]

# %% [markdown]
# ## PPI Samlet Dansk produktion

# %%
file_path = 'PPI_samlet_DK.xlsx'
PPI = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
PPI_data = standardize_dates(PPI, "date")
PPI_data
# Out:
#             BCDE Råstofindvinding, Industri, Energi- og Vandforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                1.3
# 2005-03-01                                                2.5
# 2005-04-01                                                0.8
# 2005-05-01                                                0.0
# ...                                                       ...
# 2024-11-01                                                3.5
# 2024-12-01                                                1.3
# 2025-01-01                                               -0.1
# 2025-02-01                                                0.9
# 2025-03-01                                               -2.0
#
#             BC Råstofindvinding og industri  B Råstofindvinding  \
# Date
# 2005-01-01                              NaN                 NaN
# 2005-02-01                              0.7                 5.4
# 2005-03-01                              1.4                10.3
# 2005-04-01                              1.0                 5.5
# 2005-05-01                             -0.3                -2.6
# ...                                     ...                 ...
# 2024-11-01                              2.4                 2.5
# 2024-12-01                              1.4                 1.1
# 2025-01-01                             -0.6                 1.7
# 2025-02-01                             -0.2                -0.1
# 2025-03-01                             -0.5                -2.1
#
#             C Fremstillingsvirksomhed  10 Fremstilling af fødevarer  \
# Date
# 2005-01-01                        NaN                           NaN
# 2005-02-01                        0.3                          -0.5
# 2005-03-01                        0.0                          -0.3
# 2005-04-01                        0.4                          -0.4
# 2005-05-01                       -0.1                           0.4
# ...                               ...                           ...
# 2024-11-01                        2.3                           0.2
# 2024-12-01                        1.5                           0.9
# 2025-01-01                       -0.8                           0.8
# 2025-02-01                       -0.2                          -0.2
# 2025-03-01                       -0.4                           0.2
#
#             101 Forarbejdning og konservering af kød og produktion af kødprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.0
# 2005-03-01                                                0.6
# 2005-04-01                                               -0.5
# 2005-05-01                                               -1.2
# ...                                                       ...
# 2024-11-01                                                NaN
# 2024-12-01                                                NaN
# 2025-01-01                                                NaN
# 2025-02-01                                                NaN
# 2025-03-01                                                NaN
#
#             102 Forarbejdning og konservering af fisk, krebsdyr og bløddyr  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -5.1
# 2005-03-01                                               -0.2
# 2005-04-01                                               -0.3
# 2005-05-01                                                3.0
# ...                                                       ...
# 2024-11-01                                                0.1
# 2024-12-01                                                1.6
# 2025-01-01                                                2.7
# 2025-02-01                                               -2.0
# 2025-03-01                                                0.1
#
#             105 Fremstilling af mejeriprodukter  \
# Date
# 2005-01-01                                  NaN
# 2005-02-01                                 -0.1
# 2005-03-01                                 -0.8
# 2005-04-01                                  0.0
# 2005-05-01                                  0.5
# ...                                         ...
# 2024-11-01                                  NaN
# 2024-12-01                                  NaN
# 2025-01-01                                  NaN
# 2025-02-01                                  NaN
# 2025-03-01                                  NaN
#
#             107 Fremstilling af bageri- og dejprodukter  \
# Date
# 2005-01-01                                          NaN
# 2005-02-01                                         -0.1
# 2005-03-01                                         -0.7
# 2005-04-01                                         -0.7
# 2005-05-01                                          0.7
# ...                                                 ...
# 2024-11-01                                          1.0
# 2024-12-01                                          0.2
# 2025-01-01                                          0.1
# 2025-02-01                                          0.1
# 2025-03-01                                          0.7
#
#             108 Fremstilling af andre fødevarer  ...  \
# Date                                             ...
# 2005-01-01                                  NaN  ...
# 2005-02-01                                  0.1  ...
# 2005-03-01                                 -0.8  ...
# 2005-04-01                                 -0.6  ...
# 2005-05-01                                  0.6  ...
# ...                                         ...  ...
# 2024-11-01                                  0.2  ...
# 2024-12-01                                  0.4  ...
# 2025-01-01                                  0.1  ...
# 2025-02-01                                  1.4  ...
# 2025-03-01                                  0.6  ...
#
#             32 Anden fremstillingsvirksomhed  \
# Date
# 2005-01-01                               NaN
# 2005-02-01                               0.0
# 2005-03-01                              -1.5
# 2005-04-01                               0.1
# 2005-05-01                              -0.7
# ...                                      ...
# 2024-11-01                               0.0
# 2024-12-01                               0.2
# 2025-01-01                              -0.9
# 2025-02-01                               0.0
# 2025-03-01                               0.2
#
#             D El-, gas- og fjernvarmeforsyning  S1 Investeringsgodeindustri  \
# Date
# 2005-01-01                                 NaN                          NaN
# 2005-02-01                                 NaN                          NaN
# 2005-03-01                                 NaN                          NaN
# 2005-04-01                                 NaN                          NaN
# 2005-05-01                                 NaN                          NaN
# ...                                        ...                          ...
# 2024-11-01                                16.0                          0.0
# 2024-12-01                                -0.3                         -0.1
# 2025-01-01                                 4.7                          5.5
# 2025-02-01                                11.9                          0.0
# 2025-03-01                               -14.8                          0.0
#
#             S2 Mellemproduktindustri  S3 Fremstilling af varige forbrugsgoder  \
# Date
# 2005-01-01                       NaN                                      NaN
# 2005-02-01                       0.0                                      0.1
# 2005-03-01                      -0.1                                      0.0
# 2005-04-01                       0.4                                     -0.1
# 2005-05-01                       0.4                                      0.3
# ...                              ...                                      ...
# 2024-11-01                       0.7                                      0.3
# 2024-12-01                       0.1                                      0.4
# 2025-01-01                       0.4                                      0.2
# 2025-02-01                       0.2                                      0.1
# 2025-03-01                      -0.2                                      0.0
#
#             S4 Fremstilling af ikke-varige forbrugsgoder  \
# Date
# 2005-01-01                                           NaN
# 2005-02-01                                          -0.1
# 2005-03-01                                          -0.3
# 2005-04-01                                          -0.1
# 2005-05-01                                           0.1
# ...                                                  ...
# 2024-11-01                                           0.1
# 2024-12-01                                           0.0
# 2025-01-01                                           0.8
# 2025-02-01                                           0.2
# 2025-03-01                                           0.1
#
#             S5 Fremstilling af energiprodukter og energiforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -0.2
# 2005-03-01                                                0.0
# 2005-04-01                                               -0.2
# 2005-05-01                                                0.1
# ...                                                       ...
# 2024-11-01                                                4.5
# 2024-12-01                                                2.6
# 2025-01-01                                               -3.1
# 2025-02-01                                               -0.2
# 2025-03-01                                                0.2
#
#             C33 Fremstillingsindustri ekskl. forarb. af kød og fisk samt ekskl. fremst. af tobak, koks og raffinerede mineral olieprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                5.7
# 2005-03-01                                               10.8
# 2005-04-01                                                3.5
# 2005-05-01                                               -0.8
# ...                                                       ...
# 2024-11-01                                               10.2
# 2024-12-01                                                0.8
# 2025-01-01                                                5.4
# 2025-02-01                                                5.5
# 2025-03-01                                              -11.4
#
#             S6 Fremstilling af forbrugsgoder ekskl. fødevarer  Unnamed: 39
# Date
# 2005-01-01                                                NaN          NaN
# 2005-02-01                                                NaN          NaN
# 2005-03-01                                                NaN          NaN
# 2005-04-01                                                NaN          NaN
# 2005-05-01                                                NaN          NaN
# ...                                                       ...          ...
# 2024-11-01                                                2.6          6.3
# 2024-12-01                                                1.4          3.2
# 2025-01-01                                               -1.3         -5.5
# 2025-02-01                                                0.1          0.0
# 2025-03-01                                                0.2          0.2
#
# [243 rows x 39 columns]

# %%
df_PPI_data = PPI_data.resample("MS").ffill()
df_PPI_data = df_PPI_data.add_prefix("PPI_domestic_")
df_PPI_data  # Se de første 12 måneder
# Out:
#             PPI_domestic_BCDE Råstofindvinding, Industri, Energi- og Vandforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                1.3
# 2005-03-01                                                2.5
# 2005-04-01                                                0.8
# 2005-05-01                                                0.0
# ...                                                       ...
# 2024-11-01                                                3.5
# 2024-12-01                                                1.3
# 2025-01-01                                               -0.1
# 2025-02-01                                                0.9
# 2025-03-01                                               -2.0
#
#             PPI_domestic_BC Råstofindvinding og industri  \
# Date
# 2005-01-01                                           NaN
# 2005-02-01                                           0.7
# 2005-03-01                                           1.4
# 2005-04-01                                           1.0
# 2005-05-01                                          -0.3
# ...                                                  ...
# 2024-11-01                                           2.4
# 2024-12-01                                           1.4
# 2025-01-01                                          -0.6
# 2025-02-01                                          -0.2
# 2025-03-01                                          -0.5
#
#             PPI_domestic_B Råstofindvinding  \
# Date
# 2005-01-01                              NaN
# 2005-02-01                              5.4
# 2005-03-01                             10.3
# 2005-04-01                              5.5
# 2005-05-01                             -2.6
# ...                                     ...
# 2024-11-01                              2.5
# 2024-12-01                              1.1
# 2025-01-01                              1.7
# 2025-02-01                             -0.1
# 2025-03-01                             -2.1
#
#             PPI_domestic_C Fremstillingsvirksomhed  \
# Date
# 2005-01-01                                     NaN
# 2005-02-01                                     0.3
# 2005-03-01                                     0.0
# 2005-04-01                                     0.4
# 2005-05-01                                    -0.1
# ...                                            ...
# 2024-11-01                                     2.3
# 2024-12-01                                     1.5
# 2025-01-01                                    -0.8
# 2025-02-01                                    -0.2
# 2025-03-01                                    -0.4
#
#             PPI_domestic_10 Fremstilling af fødevarer  \
# Date
# 2005-01-01                                        NaN
# 2005-02-01                                       -0.5
# 2005-03-01                                       -0.3
# 2005-04-01                                       -0.4
# 2005-05-01                                        0.4
# ...                                               ...
# 2024-11-01                                        0.2
# 2024-12-01                                        0.9
# 2025-01-01                                        0.8
# 2025-02-01                                       -0.2
# 2025-03-01                                        0.2
#
#             PPI_domestic_101 Forarbejdning og konservering af kød og produktion af kødprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.0
# 2005-03-01                                                0.6
# 2005-04-01                                               -0.5
# 2005-05-01                                               -1.2
# ...                                                       ...
# 2024-11-01                                                NaN
# 2024-12-01                                                NaN
# 2025-01-01                                                NaN
# 2025-02-01                                                NaN
# 2025-03-01                                                NaN
#
#             PPI_domestic_102 Forarbejdning og konservering af fisk, krebsdyr og bløddyr  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -5.1
# 2005-03-01                                               -0.2
# 2005-04-01                                               -0.3
# 2005-05-01                                                3.0
# ...                                                       ...
# 2024-11-01                                                0.1
# 2024-12-01                                                1.6
# 2025-01-01                                                2.7
# 2025-02-01                                               -2.0
# 2025-03-01                                                0.1
#
#             PPI_domestic_105 Fremstilling af mejeriprodukter  \
# Date
# 2005-01-01                                               NaN
# 2005-02-01                                              -0.1
# 2005-03-01                                              -0.8
# 2005-04-01                                               0.0
# 2005-05-01                                               0.5
# ...                                                      ...
# 2024-11-01                                               NaN
# 2024-12-01                                               NaN
# 2025-01-01                                               NaN
# 2025-02-01                                               NaN
# 2025-03-01                                               NaN
#
#             PPI_domestic_107 Fremstilling af bageri- og dejprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -0.1
# 2005-03-01                                               -0.7
# 2005-04-01                                               -0.7
# 2005-05-01                                                0.7
# ...                                                       ...
# 2024-11-01                                                1.0
# 2024-12-01                                                0.2
# 2025-01-01                                                0.1
# 2025-02-01                                                0.1
# 2025-03-01                                                0.7
#
#             PPI_domestic_108 Fremstilling af andre fødevarer  ...  \
# Date                                                          ...
# 2005-01-01                                               NaN  ...
# 2005-02-01                                               0.1  ...
# 2005-03-01                                              -0.8  ...
# 2005-04-01                                              -0.6  ...
# 2005-05-01                                               0.6  ...
# ...                                                      ...  ...
# 2024-11-01                                               0.2  ...
# 2024-12-01                                               0.4  ...
# 2025-01-01                                               0.1  ...
# 2025-02-01                                               1.4  ...
# 2025-03-01                                               0.6  ...
#
#             PPI_domestic_32 Anden fremstillingsvirksomhed  \
# Date
# 2005-01-01                                            NaN
# 2005-02-01                                            0.0
# 2005-03-01                                           -1.5
# 2005-04-01                                            0.1
# 2005-05-01                                           -0.7
# ...                                                   ...
# 2024-11-01                                            0.0
# 2024-12-01                                            0.2
# 2025-01-01                                           -0.9
# 2025-02-01                                            0.0
# 2025-03-01                                            0.2
#
#             PPI_domestic_D El-, gas- og fjernvarmeforsyning  \
# Date
# 2005-01-01                                              NaN
# 2005-02-01                                              NaN
# 2005-03-01                                              NaN
# 2005-04-01                                              NaN
# 2005-05-01                                              NaN
# ...                                                     ...
# 2024-11-01                                             16.0
# 2024-12-01                                             -0.3
# 2025-01-01                                              4.7
# 2025-02-01                                             11.9
# 2025-03-01                                            -14.8
#
#             PPI_domestic_S1 Investeringsgodeindustri  \
# Date
# 2005-01-01                                       NaN
# 2005-02-01                                       NaN
# 2005-03-01                                       NaN
# 2005-04-01                                       NaN
# 2005-05-01                                       NaN
# ...                                              ...
# 2024-11-01                                       0.0
# 2024-12-01                                      -0.1
# 2025-01-01                                       5.5
# 2025-02-01                                       0.0
# 2025-03-01                                       0.0
#
#             PPI_domestic_S2 Mellemproduktindustri  \
# Date
# 2005-01-01                                    NaN
# 2005-02-01                                    0.0
# 2005-03-01                                   -0.1
# 2005-04-01                                    0.4
# 2005-05-01                                    0.4
# ...                                           ...
# 2024-11-01                                    0.7
# 2024-12-01                                    0.1
# 2025-01-01                                    0.4
# 2025-02-01                                    0.2
# 2025-03-01                                   -0.2
#
#             PPI_domestic_S3 Fremstilling af varige forbrugsgoder  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.1
# 2005-03-01                                                0.0
# 2005-04-01                                               -0.1
# 2005-05-01                                                0.3
# ...                                                       ...
# 2024-11-01                                                0.3
# 2024-12-01                                                0.4
# 2025-01-01                                                0.2
# 2025-02-01                                                0.1
# 2025-03-01                                                0.0
#
#             PPI_domestic_S4 Fremstilling af ikke-varige forbrugsgoder  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -0.1
# 2005-03-01                                               -0.3
# 2005-04-01                                               -0.1
# 2005-05-01                                                0.1
# ...                                                       ...
# 2024-11-01                                                0.1
# 2024-12-01                                                0.0
# 2025-01-01                                                0.8
# 2025-02-01                                                0.2
# 2025-03-01                                                0.1
#
#             PPI_domestic_S5 Fremstilling af energiprodukter og energiforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                               -0.2
# 2005-03-01                                                0.0
# 2005-04-01                                               -0.2
# 2005-05-01                                                0.1
# ...                                                       ...
# 2024-11-01                                                4.5
# 2024-12-01                                                2.6
# 2025-01-01                                               -3.1
# 2025-02-01                                               -0.2
# 2025-03-01                                                0.2
#
#             PPI_domestic_C33 Fremstillingsindustri ekskl. forarb. af kød og fisk samt ekskl. fremst. af tobak, koks og raffinerede mineral olieprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                5.7
# 2005-03-01                                               10.8
# 2005-04-01                                                3.5
# 2005-05-01                                               -0.8
# ...                                                       ...
# 2024-11-01                                               10.2
# 2024-12-01                                                0.8
# 2025-01-01                                                5.4
# 2025-02-01                                                5.5
# 2025-03-01                                              -11.4
#
#             PPI_domestic_S6 Fremstilling af forbrugsgoder ekskl. fødevarer  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                                2.6
# 2024-12-01                                                1.4
# 2025-01-01                                               -1.3
# 2025-02-01                                                0.1
# 2025-03-01                                                0.2
#
#             PPI_domestic_Unnamed: 39
# Date
# 2005-01-01                       NaN
# 2005-02-01                       NaN
# 2005-03-01                       NaN
# 2005-04-01                       NaN
# 2005-05-01                       NaN
# ...                              ...
# 2024-11-01                       6.3
# 2024-12-01                       3.2
# 2025-01-01                      -5.5
# 2025-02-01                       0.0
# 2025-03-01                       0.2
#
# [243 rows x 39 columns]

# %% [markdown]
# ## PPI Import

# %%
file_path = 'PPI_import.xlsx'
PPI_import = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
PPI_import_data = standardize_dates(PPI_import, "date")

Df_PPI_import_data = PPI_import_data.resample("MS").ffill()
Df_PPI_import_data = Df_PPI_import_data.add_prefix("PPI_import_")
Df_PPI_import_data  # Se de første 12 måneder
# Out:
#             PPI_import_BCDE Råstofindvinding, Industri, Energi- og Vandforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.5
# 2005-03-01                                                1.0
# 2005-04-01                                               -0.2
# 2005-05-01                                                0.0
# ...                                                       ...
# 2024-11-01                                                0.9
# 2024-12-01                                                0.2
# 2025-01-01                                                0.8
# 2025-02-01                                                1.1
# 2025-03-01                                               -1.4
#
#             PPI_import_BC Råstofindvinding og industri  \
# Date
# 2005-01-01                                         NaN
# 2005-02-01                                         0.5
# 2005-03-01                                         0.7
# 2005-04-01                                        -0.2
# 2005-05-01                                         0.0
# ...                                                ...
# 2024-11-01                                         0.6
# 2024-12-01                                         0.3
# 2025-01-01                                         0.6
# 2025-02-01                                         0.4
# 2025-03-01                                        -0.2
#
#             PPI_import_B Råstofindvinding  \
# Date
# 2005-01-01                            NaN
# 2005-02-01                            3.4
# 2005-03-01                           11.5
# 2005-04-01                            0.4
# 2005-05-01                           -4.2
# ...                                   ...
# 2024-11-01                            2.2
# 2024-12-01                            0.2
# 2025-01-01                            4.9
# 2025-02-01                           -2.4
# 2025-03-01                           -1.8
#
#             PPI_import_C Fremstillingsvirksomhed  \
# Date
# 2005-01-01                                   NaN
# 2005-02-01                                   0.1
# 2005-03-01                                   0.6
# 2005-04-01                                  -0.1
# 2005-05-01                                   0.1
# ...                                          ...
# 2024-11-01                                   0.6
# 2024-12-01                                   0.2
# 2025-01-01                                   0.3
# 2025-02-01                                   0.7
# 2025-03-01                                  -0.1
#
#             PPI_import_10 Fremstilling af fødevarer  \
# Date
# 2005-01-01                                      NaN
# 2005-02-01                                      1.3
# 2005-03-01                                      1.0
# 2005-04-01                                      0.2
# 2005-05-01                                     -0.6
# ...                                             ...
# 2024-11-01                                      0.4
# 2024-12-01                                      0.0
# 2025-01-01                                      0.8
# 2025-02-01                                     -0.5
# 2025-03-01                                     -0.2
#
#             PPI_import_101 Forarbejdning og konservering af kød og produktion af kødprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                               -0.4
# 2024-12-01                                                0.1
# 2025-01-01                                               -0.7
# 2025-02-01                                               -0.7
# 2025-03-01                                                0.2
#
#             PPI_import_102 Forarbejdning og konservering af fisk, krebsdyr og bløddyr  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                               -0.3
# 2024-12-01                                                1.4
# 2025-01-01                                               -0.4
# 2025-02-01                                                1.1
# 2025-03-01                                               -2.5
#
#             PPI_import_105 Fremstilling af mejeriprodukter  \
# Date
# 2005-01-01                                             NaN
# 2005-02-01                                             NaN
# 2005-03-01                                             NaN
# 2005-04-01                                             NaN
# 2005-05-01                                             NaN
# ...                                                    ...
# 2024-11-01                                             2.1
# 2024-12-01                                             0.8
# 2025-01-01                                             0.9
# 2025-02-01                                             2.8
# 2025-03-01                                            -0.1
#
#             PPI_import_107 Fremstilling af bageri- og dejprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                               -0.6
# 2024-12-01                                               -0.1
# 2025-01-01                                                1.6
# 2025-02-01                                               -0.6
# 2025-03-01                                               -0.2
#
#             PPI_import_108 Fremstilling af andre fødevarer  ...  \
# Date                                                        ...
# 2005-01-01                                             NaN  ...
# 2005-02-01                                             NaN  ...
# 2005-03-01                                             NaN  ...
# 2005-04-01                                             NaN  ...
# 2005-05-01                                             NaN  ...
# ...                                                    ...  ...
# 2024-11-01                                             0.8  ...
# 2024-12-01                                            -0.7  ...
# 2025-01-01                                             1.7  ...
# 2025-02-01                                            -1.9  ...
# 2025-03-01                                             0.7  ...
#
#             PPI_import_31 Fremstilling af møbler  \
# Date
# 2005-01-01                                   NaN
# 2005-02-01                                  -0.1
# 2005-03-01                                   1.4
# 2005-04-01                                   0.0
# 2005-05-01                                   0.6
# ...                                          ...
# 2024-11-01                                   0.1
# 2024-12-01                                   0.2
# 2025-01-01                                   2.2
# 2025-02-01                                   0.7
# 2025-03-01                                   0.3
#
#             PPI_import_32 Anden fremstillingsvirksomhed  \
# Date
# 2005-01-01                                          NaN
# 2005-02-01                                          0.3
# 2005-03-01                                          0.4
# 2005-04-01                                         -0.4
# 2005-05-01                                         -0.1
# ...                                                 ...
# 2024-11-01                                          0.5
# 2024-12-01                                          0.6
# 2025-01-01                                          0.1
# 2025-02-01                                          0.1
# 2025-03-01                                          0.3
#
#             PPI_import_D El-, gas- og fjernvarmeforsyning  \
# Date
# 2005-01-01                                            NaN
# 2005-02-01                                           20.5
# 2005-03-01                                           16.8
# 2005-04-01                                           -7.2
# 2005-05-01                                           -3.5
# ...                                                   ...
# 2024-11-01                                           82.0
# 2024-12-01                                           -0.9
# 2025-01-01                                            5.2
# 2025-02-01                                           24.7
# 2025-03-01                                          -35.7
#
#             PPI_import_S1 Investeringsgodeindustri  \
# Date
# 2005-01-01                                     NaN
# 2005-02-01                                     0.4
# 2005-03-01                                    -0.7
# 2005-04-01                                    -0.1
# 2005-05-01                                    -0.7
# ...                                            ...
# 2024-11-01                                     0.6
# 2024-12-01                                     0.3
# 2025-01-01                                    -0.2
# 2025-02-01                                    -0.1
# 2025-03-01                                    -0.4
#
#             PPI_import_S2 Mellemproduktindustri  \
# Date
# 2005-01-01                                  NaN
# 2005-02-01                                  0.0
# 2005-03-01                                  0.1
# 2005-04-01                                 -0.3
# 2005-05-01                                  0.5
# ...                                         ...
# 2024-11-01                                  0.2
# 2024-12-01                                  0.3
# 2025-01-01                                 -0.1
# 2025-02-01                                  0.8
# 2025-03-01                                  0.3
#
#             PPI_import_S3 Fremstilling af varige forbrugsgoder  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.2
# 2005-03-01                                                0.7
# 2005-04-01                                                0.0
# 2005-05-01                                                0.4
# ...                                                       ...
# 2024-11-01                                                0.0
# 2024-12-01                                                0.2
# 2025-01-01                                                0.5
# 2025-02-01                                                0.2
# 2025-03-01                                                0.1
#
#             PPI_import_S4 Fremstilling af ikke-varige forbrugsgoder  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                0.6
# 2005-03-01                                                0.5
# 2005-04-01                                                0.0
# 2005-05-01                                               -0.2
# ...                                                       ...
# 2024-11-01                                                0.7
# 2024-12-01                                               -0.2
# 2025-01-01                                                0.6
# 2025-02-01                                                1.7
# 2025-03-01                                                1.1
#
#             PPI_import_S5 Fremstilling af energiprodukter og energiforsyning  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                4.4
# 2005-03-01                                               14.4
# 2005-04-01                                               -2.0
# 2005-05-01                                                1.3
# ...                                                       ...
# 2024-11-01                                                6.2
# 2024-12-01                                                0.7
# 2025-01-01                                                5.0
# 2025-02-01                                                3.5
# 2025-03-01                                              -13.0
#
#             PPI_import_C33 Fremstillingsindustri ekskl. forarb. af kød og fisk samt ekskl. fremst. af tobak, koks og raffinerede mineral olieprodukter  \
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                                0.4
# 2024-12-01                                                0.2
# 2025-01-01                                                0.2
# 2025-02-01                                                0.8
# 2025-03-01                                                0.4
#
#             PPI_import_S6 Fremstilling af forbrugsgoder ekskl. fødevarer
# Date
# 2005-01-01                                                NaN
# 2005-02-01                                                NaN
# 2005-03-01                                                NaN
# 2005-04-01                                                NaN
# 2005-05-01                                                NaN
# ...                                                       ...
# 2024-11-01                                                0.6
# 2024-12-01                                               -0.2
# 2025-01-01                                                0.4
# 2025-02-01                                                2.4
# 2025-03-01                                                1.5
#
# [243 rows x 38 columns]

# %% [markdown]
# ## Bil data

# %%
file_path = 'bil_data.xlsx'
bil_data = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
bil_data = standardize_dates(bil_data, "date")

df_bil_data = bil_data.resample("MS").ffill()
df_bil_data  # Se de første 12 måneder
# Out:
#             Personbiler i alt  Tilgang af personbiler i alt, sæsonkorrigeret  \
# Date
# 2007-01-01              11684                                          12154
# 2007-02-01              10810                                          12732
# 2007-03-01              14443                                          13020
# 2007-04-01              12274                                          12552
# 2007-05-01              14342                                          12854
# ...                       ...                                            ...
# 2024-10-01              14385                                          15101
# 2024-11-01              14955                                          14924
# 2024-12-01              17431                                          14905
# 2025-01-01              10859                                          13440
# 2025-02-01              11683                                          13872
#
#             Tilgang til husholdningerne  \
# Date
# 2007-01-01                         8250
# 2007-02-01                         6974
# 2007-03-01                         9481
# 2007-04-01                         8286
# 2007-05-01                         9369
# ...                                 ...
# 2024-10-01                         8745
# 2024-11-01                         8700
# 2024-12-01                         9728
# 2025-01-01                         6867
# 2025-02-01                         7358
#
#             Tilgang til husholdningerne, sæsonkorrigeret  \
# Date
# 2007-01-01                                          8033
# 2007-02-01                                          7984
# 2007-03-01                                          8155
# 2007-04-01                                          8037
# 2007-05-01                                          8272
# ...                                                  ...
# 2024-10-01                                          9214
# 2024-11-01                                          9122
# 2024-12-01                                          8768
# 2025-01-01                                          7744
# 2025-02-01                                          8007
#
#             Personbiler i husholdningerne  Privatleasing  \
# Date
# 2007-01-01                           8015            235
# 2007-02-01                           6760            214
# 2007-03-01                           9200            281
# 2007-04-01                           8077            209
# 2007-05-01                           9093            276
# ...                                   ...            ...
# 2024-10-01                           5222           3523
# 2024-11-01                           5359           3341
# 2024-12-01                           5701           4027
# 2025-01-01                           4382           2485
# 2025-02-01                           4423           2935
#
#             Tilgang til erhvervene  Tilgang til erhvervene, sæsonkorrigeret  \
# Date
# 2007-01-01                    3434                                     4122
# 2007-02-01                    3836                                     4748
# 2007-03-01                    4962                                     4866
# 2007-04-01                    3988                                     4515
# 2007-05-01                    4973                                     4582
# ...                            ...                                      ...
# 2024-10-01                    5640                                     5887
# 2024-11-01                    6255                                     5802
# 2024-12-01                    7703                                     6137
# 2025-01-01                    3992                                     5695
# 2025-02-01                    4325                                     5864
#
#             Erhvervenes køb af personbiler  Erhvervsleasing  \
# Date
# 2007-01-01                            1955             1479
# 2007-02-01                            2003             1833
# 2007-03-01                            2762             2200
# 2007-04-01                            2102             1886
# 2007-05-01                            2850             2123
# ...                                    ...              ...
# 2024-10-01                             831             4809
# 2024-11-01                             750             5505
# 2024-12-01                             893             6810
# 2025-01-01                             738             3254
# 2025-02-01                             519             3806
#
#             Leasingbiler i alt
# Date
# 2007-01-01                1714
# 2007-02-01                2047
# 2007-03-01                2481
# 2007-04-01                2095
# 2007-05-01                2399
# ...                        ...
# 2024-10-01                8332
# 2024-11-01                8846
# 2024-12-01               10837
# 2025-01-01                5739
# 2025-02-01                6741
#
# [218 rows x 11 columns]

# %% [markdown]
# ## Konjunkturbarometer

# %%
file_path = 'Konjunkturbarometer.xlsx'
konjunkturbarometer = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
konjunkturbarometer_data = standardize_dates(konjunkturbarometer, "date")

df_konjunkturbarometer = konjunkturbarometer_data.resample("MS").ffill()
df_konjunkturbarometer  # Se de første 12 måneder
# Out:
#             Tillidsindikator for industri  \
# Date
# 2001-01-01                          104.6
# 2001-02-01                          103.7
# 2001-03-01                          105.2
# 2001-04-01                           96.1
# 2001-05-01                           95.9
# ...                                   ...
# 2024-12-01                          104.8
# 2025-01-01                          105.3
# 2025-02-01                          107.3
# 2025-03-01                          107.2
# 2025-04-01                          103.6
#
#             Tillidsindikator for bygge og anlæg  \
# Date
# 2001-01-01                                 98.8
# 2001-02-01                                 96.8
# 2001-03-01                                 95.7
# 2001-04-01                                 97.9
# 2001-05-01                                 95.4
# ...                                         ...
# 2024-12-01                                104.3
# 2025-01-01                                102.9
# 2025-02-01                                101.6
# 2025-03-01                                101.3
# 2025-04-01                                100.0
#
#             Tillidsindikator for detailhandel  \
# Date
# 2001-01-01                               93.4
# 2001-02-01                               93.3
# 2001-03-01                               83.7
# 2001-04-01                               89.6
# 2001-05-01                               84.7
# ...                                       ...
# 2024-12-01                              103.6
# 2025-01-01                               94.6
# 2025-02-01                              102.5
# 2025-03-01                               98.6
# 2025-04-01                              102.3
#
#             Tillidsindikator for serviceerhverv
# Date
# 2001-01-01                                103.1
# 2001-02-01                                102.1
# 2001-03-01                                100.6
# 2001-04-01                                 98.2
# 2001-05-01                                 99.9
# ...                                         ...
# 2024-12-01                                104.8
# 2025-01-01                                104.5
# 2025-02-01                                107.0
# 2025-03-01                                105.2
# 2025-04-01                                104.4
#
# [292 rows x 4 columns]

# %% [markdown]
# ## total energi produktion

# %%
file_path = 'Energi_data.xlsx'
energi_data = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
energi_data = standardize_dates(energi_data, "year")

df_energi_data = energi_data.resample("MS").ffill()
df_energi_data  # Se de første 12 måneder
# Out:
#                     Total           Oil     Natural Gas  Coal and Coke  \
# Date
# 2005-01-01  838813.500833  352523.131082  187220.096164  155255.093500
# 2005-02-01  838813.500833  352523.131082  187220.096164  155255.093500
# 2005-03-01  838813.500833  352523.131082  187220.096164  155255.093500
# 2005-04-01  838813.500833  352523.131082  187220.096164  155255.093500
# 2005-05-01  838813.500833  352523.131082  187220.096164  155255.093500
# ...                   ...            ...            ...            ...
# 2023-09-01  691190.009378  280334.613725   55972.345225   27945.351829
# 2023-10-01  691190.009378  280334.613725   55972.345225   27945.351829
# 2023-11-01  691190.009378  280334.613725   55972.345225   27945.351829
# 2023-12-01  691190.009378  280334.613725   55972.345225   27945.351829
# 2024-01-01  687205.974037  267182.405556   56225.192120   19139.381184
#
#             Waste, Non-renewable 2)  Renewable Energy 3)  \
# Date
# 2005-01-01                 17006.34        121877.068925
# 2005-02-01                 17006.34        121877.068925
# 2005-03-01                 17006.34        121877.068925
# 2005-04-01                 17006.34        121877.068925
# 2005-05-01                 17006.34        121877.068925
# ...                             ...                  ...
# 2023-09-01                 17349.33        298308.090000
# 2023-10-01                 17349.33        298308.090000
# 2023-11-01                 17349.33        298308.090000
# 2023-12-01                 17349.33        298308.090000
# 2024-01-01                 17349.33        313949.778268
#
#             Electricity Import, Net
# Date
# 2005-01-01              4931.771162
# 2005-02-01              4931.771162
# 2005-03-01              4931.771162
# 2005-04-01              4931.771162
# 2005-05-01              4931.771162
# ...                             ...
# 2023-09-01             11280.278599
# 2023-10-01             11280.278599
# 2023-11-01             11280.278599
# 2023-12-01             11280.278599
# 2024-01-01             13359.886909
#
# [229 rows x 7 columns]

# %% [markdown]
# ## Detailomsætningsindeks

# %%
file_path = 'Detailomsætningsindeks.xlsx'
detailomsætningsindeks = pd.read_excel(file_path, header=0, decimal=",")

# Kør standardiseringsfunktionen
detailomsætningsindeks_data = standardize_dates(detailomsætningsindeks, "date")
detailomsætningsindeks_data.rename(columns={"Detailhandel i alt": "Detailhandel i alt (indeks)"}, inplace=True)


df_detailomsætningsindeks= detailomsætningsindeks_data.resample("MS").ffill()
df_detailomsætningsindeks  # Se de første 12 måneder
# Out:
#             Detailhandel i alt (indeks)
# Date
# 2001-01-01                         86.0
# 2001-02-01                         85.6
# 2001-03-01                         85.1
# 2001-04-01                         84.6
# 2001-05-01                         85.7
# ...                                 ...
# 2024-11-01                         95.7
# 2024-12-01                         95.8
# 2025-01-01                         96.0
# 2025-02-01                         96.8
# 2025-03-01                         96.6
#
# [291 rows x 1 columns]

# %% [markdown]
# ## ECB data

# %%
# Læs filen som rå tekst først
with open('ECB_inflation.csv', 'r') as file:
    lines = file.readlines()

# Split hver linje ved komma
data = [line.strip().split(',') for line in lines]

# Konvertér til DataFrame
columns = [col.strip('"') for col in data[0]] # Første linje = kolonnenavne
rows = [[item.strip('"') for item in row] for row in data[1:]]


# Lav DataFrame
ECB = pd.DataFrame(rows, columns=columns)

# Konverter datatyper
ECB['DATE'] = pd.to_datetime(ECB['DATE'])
ECB[ECB.columns[2]] = ECB[ECB.columns[2]].astype(float)
ECB = ECB.drop(columns=['TIME PERIOD'])
ECB.rename(columns={"HICP - Overall index (ICP.M.U2.N.000000.4.ANR)": "HICP, EU (inflation)"}, inplace=True)


ECB
# Out:
#           DATE  HICP, EU (inflation)
# 0   1997-01-31                   2.0
# 1   1997-02-28                   1.8
# 2   1997-03-31                   1.6
# 3   1997-04-30                   1.3
# 4   1997-05-31                   1.4
# ..         ...                   ...
# 335 2024-12-31                   2.4
# 336 2025-01-31                   2.5
# 337 2025-02-28                   2.3
# 338 2025-03-31                   2.2
# 339 2025-04-30                   2.2
#
# [340 rows x 2 columns]

# %%
# Kør standardiseringsfunktionen
df_ECB = standardize_dates(ECB, "DATE")

# Se det nye format
df_ECB.head()
# Out:
#             HICP, EU (inflation)
# Date
# 1997-01-01                   2.0
# 1997-02-01                   1.8
# 1997-03-01                   1.6
# 1997-04-01                   1.3
# 1997-05-01                   1.4

# %% [markdown]
# ## HPI

# %%
file_path = 'HPI.csv'
HPI = pd.read_csv(file_path, sep=';', encoding='ISO-8859-1', header=0)

# Kør standardiseringsfunktionen
df_hpi = standardize_dates(HPI, "date")

# Se det nye format
df_hpi.head()
# Out:
#              HPI
# Date
# 2002-10-01  59.8
# 2003-01-01  60.7
# 2003-04-01  62.0
# 2003-07-01  63.1
# 2003-10-01  63.3

# %%
# ME = Month-END
# MS = Month-Start
df_hpi = df_hpi.resample("MS").ffill()
df_hpi  # Se de første 12 måneder
# Out:
#               HPI
# Date
# 2002-10-01   59.8
# 2002-11-01   59.8
# 2002-12-01   59.8
# 2003-01-01   60.7
# 2003-02-01   60.7
# ...           ...
# 2024-03-01  136.7
# 2024-04-01  140.9
# 2024-05-01  140.9
# 2024-06-01  140.9
# 2024-07-01  144.4
#
# [262 rows x 1 columns]

# %% [markdown]
# ## C25-indekset

# %%
file_path = 'OMXC25.xlsx'
OMXC25 = pd.read_excel(file_path, header=0, decimal=",")

# %%
# Kør standardiseringsfunktionen
OMXC25_data = standardize_dates(OMXC25, "Trade Date")
OMXC25_data
# Out:
#             Index Value  Net Change         High          Low
# Date
# 2025-05-01  1708.699609   40.833991  1709.788568  1686.391907
# 2025-05-01  1667.865618   12.048755  1680.178480  1661.964238
# 2025-04-01  1655.816863   36.483763  1666.565697  1622.069129
# 2025-04-01  1619.333100   10.790351  1623.768934  1601.482044
# 2025-04-01  1608.542750   10.870738  1610.189482  1596.984316
# ...                 ...         ...          ...          ...
# 2010-12-01   544.353310    0.000000     0.000000     0.000000
# 2010-12-01   546.605932    0.000000     0.000000     0.000000
# 2010-12-01   542.778001    0.000000     0.000000     0.000000
# 2010-12-01   544.980134    0.000000     0.000000     0.000000
# 2010-12-01   542.094259    0.000000     0.000000     0.000000
#
# [3594 rows x 4 columns]

# %%
monthly = OMXC25_data["Index Value"].resample("MS").last()
df_OMXC25 = monthly.to_frame(name="C25 Index Value")
df_OMXC25
# Out:
#             C25 Index Value
# Date
# 2010-12-01       542.094259
# 2011-01-01       554.828386
# 2011-02-01       561.612691
# 2011-03-01       552.990574
# 2011-04-01       554.164119
# ...                     ...
# 2025-01-01      1807.253681
# 2025-02-01      1743.397378
# 2025-03-01      1849.265501
# 2025-04-01      1675.536415
# 2025-05-01      1667.865618
#
# [174 rows x 1 columns]

# %% [markdown]
# # Merge dataframes

# %% [markdown]
# ## Case 1

# %%
dfs = [df_inflation, df_ledige_procent, df_børn, df_econ_indikator, df_valutakurser, 
       df_transaktioner_medkort, df_ejendomsalg, df_hpi, df_folkekirken_medlemmer, df_total_skilsmisser, 
       df_total_hustande, df_fertilitetskvotienter, df_implicit_lønindeks,
       df_antal_beskæftigede, df_forbrugerforventninger, df_antal_ledige, df_befolkningens_udvikling, df_antal_kontanthjælp, df_antal_overtrædelse,
       df_bil_data, df_energi_data, df_vielser, Df_PPI_import_data, df_PPI_data, df_konjunkturbarometer, df_detailomsætningsindeks, df_ECB, df_OMXC25,
       df_lagged_inflation] #, , ] # # "    , df_niveau_1 df_niveau_2 df_niveau_0 df_niveau_1, df_niveau_2, df_niveau_0


# Merge 
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='outer'), dfs)

# Vigtigt!!
#df_merged = df_merged.loc["2008-01-01":"2025-01-01"]
df_merged = df_merged.loc["2012-01-01":"2024-12-01"]

# check missing values
missing_info = check_missing_values(df_merged)  


# Delete the last row, to match inflation
#df_merged = df_merged.iloc[:-1]  # Fjerner sidste række

# Display
df_merged
# Out:
# Total missing values in dataset: 980
#             Inflation  Bruttoledige (i pct. af arbejdsstyrken)  F¿dte Drenge  \
# Date
# 2012-01-01      2.763                                      5.9       29785.0
# 2012-02-01      2.731                                      6.0       29785.0
# 2012-03-01      2.610                                      6.1       29785.0
# 2012-04-01      2.183                                      6.2       29785.0
# 2012-05-01      2.181                                      6.2       29785.0
# ...               ...                                      ...           ...
# 2024-08-01      1.359                                      2.9       29501.0
# 2024-09-01      1.278                                      2.9       29501.0
# 2024-10-01      1.614                                      2.9       29501.0
# 2024-11-01      1.620                                      2.9       29501.0
# 2024-12-01      1.885                                      2.9       29501.0
#
#             F¿dte Piger  B.1*g Bruttonationalprodukt, BNP  \
# Date
# 2012-01-01      28131.0                             467.5
# 2012-02-01      28131.0                             467.5
# 2012-03-01      28131.0                             467.5
# 2012-04-01      28131.0                             472.9
# 2012-05-01      28131.0                             472.9
# ...                 ...                               ...
# 2024-08-01      27578.0                             748.6
# 2024-09-01      27578.0                             748.6
# 2024-10-01      27578.0                             769.2
# 2024-11-01      27578.0                             769.2
# 2024-12-01      27578.0                             769.2
#
#             P.7 Import af varer og tjenester  P.71 Import af varer  \
# Date
# 2012-01-01                             231.9                 143.8
# 2012-02-01                             231.9                 143.8
# 2012-03-01                             231.9                 143.8
# 2012-04-01                             232.9                 144.9
# 2012-05-01                             232.9                 144.9
# ...                                      ...                   ...
# 2024-08-01                             430.6                 231.6
# 2024-09-01                             430.6                 231.6
# 2024-10-01                             438.8                 236.8
# 2024-11-01                             438.8                 236.8
# 2024-12-01                             438.8                 236.8
#
#             P.72 Import af tjenester  Forsyning i alt  \
# Date
# 2012-01-01                      88.1            699.4
# 2012-02-01                      88.1            699.4
# 2012-03-01                      88.1            699.4
# 2012-04-01                      88.1            705.9
# 2012-05-01                      88.1            705.9
# ...                              ...              ...
# 2024-08-01                     198.9           1179.2
# 2024-09-01                     198.9           1179.2
# 2024-10-01                     202.0           1208.0
# 2024-11-01                     202.0           1208.0
# 2024-12-01                     202.0           1208.0
#
#             P.6 Eksport af varer og tjenester  ...  inflation_lag3  \
# Date                                           ...
# 2012-01-01                              255.1  ...           2.772
# 2012-02-01                              255.1  ...           2.556
# 2012-03-01                              255.1  ...           2.447
# 2012-04-01                              264.6  ...           2.763
# 2012-05-01                              264.6  ...           2.731
# ...                                       ...  ...             ...
# 2024-08-01                              524.4  ...           2.155
# 2024-09-01                              524.4  ...           1.804
# 2024-10-01                              552.2  ...           1.097
# 2024-11-01                              552.2  ...           1.359
# 2024-12-01                              552.2  ...           1.278
#
#             inflation_lag4  inflation_lag5  inflation_lag6  inflation_lag7  \
# Date
# 2012-01-01           2.556           2.564           3.004           3.001
# 2012-02-01           2.772           2.556           2.564           3.004
# 2012-03-01           2.556           2.772           2.556           2.564
# 2012-04-01           2.447           2.556           2.772           2.556
# 2012-05-01           2.763           2.447           2.556           2.772
# ...                    ...             ...             ...             ...
# 2024-08-01           0.765           0.938           0.766           1.203
# 2024-09-01           2.155           0.765           0.938           0.766
# 2024-10-01           1.804           2.155           0.765           0.938
# 2024-11-01           1.097           1.804           2.155           0.765
# 2024-12-01           1.359           1.097           1.804           2.155
#
#             inflation_lag8  inflation_lag9  inflation_lag10  inflation_lag11  \
# Date
# 2012-01-01           3.105           2.998            2.680            2.697
# 2012-02-01           3.001           3.105            2.998            2.680
# 2012-03-01           3.004           3.001            3.105            2.998
# 2012-04-01           2.564           3.004            3.001            3.105
# 2012-05-01           2.556           2.564            3.004            3.001
# ...                    ...             ...              ...              ...
# 2024-08-01           0.690           0.600            0.085            0.859
# 2024-09-01           1.203           0.690            0.600            0.085
# 2024-10-01           0.766           1.203            0.690            0.600
# 2024-11-01           0.938           0.766            1.203            0.690
# 2024-12-01           0.765           0.938            0.766            1.203
#
#             inflation_lag12
# Date
# 2012-01-01            2.729
# 2012-02-01            2.697
# 2012-03-01            2.680
# 2012-04-01            2.998
# 2012-05-01            3.105
# ...                     ...
# 2024-08-01            2.437
# 2024-09-01            0.859
# 2024-10-01            0.085
# 2024-11-01            0.600
# 2024-12-01            0.690
#
# [156 rows x 219 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 156 entries, 2012-01-01 to 2024-12-01
# Columns: 219 entries, Inflation to inflation_lag12
# dtypes: float64(219)
# memory usage: 268.1 KB

# %%
df_merged.describe()
# Out:
#         Inflation  Bruttoledige (i pct. af arbejdsstyrken)  F¿dte Drenge  \
# count  156.000000                               156.000000    156.000000
# mean     1.682872                                 4.127564  30521.923077
# std      2.167895                                 1.076168   1172.574964
# min     -0.101000                                 2.400000  28590.000000
# 25%      0.505000                                 3.150000  29554.000000
# 50%      0.804500                                 4.100000  30128.000000
# 75%      1.811500                                 4.800000  31519.000000
# max     10.112000                                 6.200000  32572.000000
#
#         F¿dte Piger  B.1*g Bruttonationalprodukt, BNP  \
# count    156.000000                        156.000000
# mean   28855.461538                        580.242308
# std     1125.715024                         88.103217
# min    27283.000000                        467.500000
# 25%    27915.000000                        505.700000
# 50%    28357.000000                        555.350000
# 75%    29833.000000                        656.350000
# max    30901.000000                        769.200000
#
#        P.7 Import af varer og tjenester  P.71 Import af varer  \
# count                        156.000000            156.000000
# mean                         306.161538            180.640385
# std                           73.545878             35.822948
# min                          230.500000            141.700000
# 25%                          246.750000            151.050000
# 50%                          280.750000            170.250000
# 75%                          350.550000            210.100000
# max                          448.700000            261.400000
#
#        P.72 Import af tjenester  Forsyning i alt  \
# count                156.000000       156.000000
# mean                 125.519231       886.405769
# std                   38.585124       160.952410
# min                   87.600000       699.400000
# 25%                   94.550000       754.325000
# 50%                  110.000000       844.050000
# 75%                  140.525000      1006.900000
# max                  202.000000      1208.000000
#
#        P.6 Eksport af varer og tjenester  ...  inflation_lag3  inflation_lag4  \
# count                         156.000000  ...      156.000000      156.000000
# mean                          347.478846  ...        1.699897        1.708090
# std                            89.761795  ...        2.171519        2.172327
# min                           255.100000  ...       -0.101000       -0.101000
# 25%                           277.775000  ...        0.505000        0.505000
# 50%                           311.050000  ...        0.804500        0.804500
# 75%                           390.050000  ...        2.096500        2.161500
# max                           552.200000  ...       10.112000       10.112000
#
#        inflation_lag5  inflation_lag6  inflation_lag7  inflation_lag8  \
# count      156.000000      156.000000      156.000000      156.000000
# mean         1.715814        1.728038        1.735712        1.741801
# std          2.173220        2.175080        2.177459        2.179967
# min         -0.101000       -0.101000       -0.101000       -0.101000
# 25%          0.505000        0.505000        0.505000        0.505000
# 50%          0.804500        0.804500        0.804500        0.804500
# 75%          2.181500        2.183500        2.194250        2.237750
# max         10.112000       10.112000       10.112000       10.112000
#
#        inflation_lag9  inflation_lag10  inflation_lag11  inflation_lag12
# count      156.000000       156.000000       156.000000       156.000000
# mean         1.756115         1.767282         1.779660         1.789442
# std          2.180842         2.181086         2.180846         2.181665
# min         -0.101000        -0.101000        -0.101000        -0.101000
# 25%          0.505000         0.505000         0.505000         0.505000
# 50%          0.813500         0.813500         0.836500         0.836500
# 75%          2.286750         2.315500         2.398750         2.439500
# max         10.112000        10.112000        10.112000        10.112000
#
# [8 rows x 219 columns]

# %%
#df_inflation = df_inflation.loc[df_merged.index]

# %%
columns_list = list(df_merged.columns)
print(columns_list)
# Out:
# ['Inflation', 'Bruttoledige (i pct. af arbejdsstyrken)', 'F¿dte Drenge', 'F¿dte Piger', 'B.1*g Bruttonationalprodukt, BNP', 'P.7 Import af varer og tjenester', 'P.71 Import af varer', 'P.72 Import af tjenester', 'Forsyning i alt', 'P.6 Eksport af varer og tjenester', 'P.61 Eksport af varer', 'P.62 Eksport af tjenester', 'P.31 Privatforbrug', 'P.31 Husholdningernes forbrugsudgifter', 'Køb af køretøjer', 'Andre varer', 'Tjenester i alt inkl. turisme', 'Tjenester i alt', 'Turistudgifter', 'Turistindtægter', 'P.31 Forbrugsudgifter i non-profit institutioner rettet mod husholdninger (NPISH)', 'P.3 Offentlige forbrugsudgifter', 'P.5g Bruttoinvesteringer', 'P.51g Faste bruttoinvesteringer', 'N.111 Boliger', 'N.112 Andre bygninger og anlæg', 'N.113-N.115 Maskiner, transportmidler mv.', 'N.117 Intellektuelle rettigheder', 'P.52+P.53 Lagerforøgelser mv.', 'P.52 Lagerforøgelser', 'P.53 Anskaffelser minus afhændelser af værdigenstande', 'Endelig indenlandsk anvendelse', 'Endelig anvendelse i alt', 'Samlede præsterede timer (mio. timer)', 'Samlet antal beskæftigede (1000 personer)', 'EUR Euro  (Jan. 1999-)', 'USD Amerikanske dollar  (Jan. 1979-)', 'GBP Britiske pund  (Jan. 1981-)', 'SEK Svenske kroner  (Jan. 1980-)', 'Transaktioner - Værdi (kr.)', 'Antal transaktioner med kort (stk.)', 'Total salg af Enfamiliehuse', 'Total salg af Sommerhuse', 'Total salg af Ejerlejligheder', 'HPI', 'Medlemmer af Folkekirken', 'Antal Skilsmisser', 'Hustande, Hele landet', 'Samlet fertilitet', 'Implicit_lønindeks_Forskning og udvikling', 'Implicit_lønindeks_P Undervisning', 'Implicit_lønindeks_R Kultur og fritid', 'Implicit_lønindeks_2 Industri, råstofindvinding og forsyningsvirksomhed', 'Implicit_lønindeks_3 Bygge og anlæg', 'Implicit_lønindeks_4 Handel og transport mv.', 'Implicit_lønindeks_5 Information og kommunikation', 'Implicit_lønindeks_6 Finansiering og forsikring', 'Implicit_lønindeks_7 Ejendomshandel og udlejning', 'Implicit_lønindeks_8 Erhvervsservice', 'Implicit_lønindeks_10 Kultur, fritid og anden service', 'Beskæftigede Mænd', 'Beskæftigede Kvinder', 'Forbrugertillidsindikatoren', 'Familiens økonomiske situation i dag, sammenlignet med for et år siden', 'Familiens økonomiske  situation om et år, sammenlignet med i dag', 'Danmarks økonomiske situation i dag, sammenlignet med for et år siden', 'Danmarks økonomiske situation om et år, sammenlignet med i dag', 'Anskaffelse af større forbrugsgoder, fordelagtigt for øjeblikket', 'Priser i dag, sammenlignet med for et år siden', 'Priser om et år, sammenlignet med i dag', 'Arbejdsløsheden om et år, sammenlignet med i dag', 'Anskaffelse af større forbrugsgoder, inden for de næste 12 mdr.', 'Anser det som fornuftigt at spare op i den nuværende økonomiske situation', 'Regner med at kunne spare op i de kommende 12 måneder', 'Familiens økonomiske situation lige nu: kan spare/penge slår til/ bruger mere end man tjener', 'Bruttoledige', 'Ledige dagpengemodtagere', 'Ledige kontanthjælpsmodtagere', 'Befolkningen ultimo forrige kvartal', 'Levendefødte', 'Døde', 'Fødselsoverskud', 'Tilflyttede', 'Fraflyttede', 'Nettotilflyttede', 'Indvandrede i alt', 'Indvandret i indeværende kvartal', 'Indvandret før indeværende kvartal', 'Udvandrede i alt', 'Udvandret i indeværende kvartal', 'Udvandret før indeværende kvartal', 'Nettoindvandrede', 'Korrektioner', 'Befolkningstilvækst', 'Befolkningen ultimo indeværende kvartal', 'Kontanthjælp, I alt', 'Overtrædelsens art i alt', 'Straffelov i alt', 'Seksualforbrydelser i alt', 'Voldsforbrydelser i alt', 'Ejendomsforbrydelser i alt', 'Særlove i alt', 'Personbiler i alt', 'Tilgang af personbiler i alt, sæsonkorrigeret', 'Tilgang til husholdningerne', 'Tilgang til husholdningerne, sæsonkorrigeret', 'Personbiler i husholdningerne', 'Privatleasing', 'Tilgang til erhvervene', 'Tilgang til erhvervene, sæsonkorrigeret', 'Erhvervenes køb af personbiler', 'Erhvervsleasing', 'Leasingbiler i alt', 'Total', 'Oil ', 'Natural Gas', 'Coal and Coke', 'Waste, Non-renewable 2)', 'Renewable Energ ...

# %%
# Skriv til tekstfil
with open("variabler.txt", "w", encoding="utf-8") as f:
    for var in columns_list:
        f.write(var + "\n")

# %% [markdown]
# # Standardize

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy="median")  # Eller "median"

X_imputed = imputer.fit_transform(df_merged)  # Imputer NaN i hele datasættet

# Konverter tilbage til DataFrame med kolonnenavne
X_new = pd.DataFrame(X_imputed, columns=df_merged.columns, index = df_merged.index)
missing_info = check_missing_values(X_new)
# Out:
# Total missing values in dataset: 0

# %%
# Save
save_merged_data(X_new, filename = "Merged_dataset.csv")
# Out:
# ✅ Filen 'Merged_dataset.csv' er gemt!

# %%
print(f" {X_new.isna().sum().sum()}")
# Out:
#  0

# %% [markdown]
# # Correlation matrix

# %%
corr_with_inflation = df_merged.corr()["Inflation"].sort_values(ascending=False)
top_corr = corr_with_inflation.drop("Inflation").head(20)

plt.figure(figsize=(8, 6))
top_corr.plot(kind="barh")
plt.title("Top 20 variables correlated with Inflation")
plt.xlabel("Pearson correlation")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Beregn korrelationsmatrix
corr_matrix = df_merged.corr()

# Plot heatmap
plt.figure(figsize=(18, 14))  # Tilpas størrelsen efter behov
sns.heatmap(corr_matrix, cmap="coolwarm", center=0, linewidths=0.5)
plt.title("Correlation Heatmap of All Variables")
plt.tight_layout()
plt.show()

# %%
#sns.clustermap(corr_matrix, cmap="coolwarm", figsize=(15, 15))

# %%
# Top 20 features correlated with 'Inflation'
target = "Inflation"
top_corr_vars = df_merged.corr()[target].abs().sort_values(ascending=False).head(25).index  # incl. 'Inflation'
subset_corr = df_merged[top_corr_vars].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(subset_corr, fmt=".2f", cmap="coolwarm", center=0) # annot=True
plt.title("Correlation Heatmap: Top 20 Variables Related to Inflation")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 14))  # Øg bredde og højde
sns.heatmap(subset_corr, cmap="coolwarm", center=0)

plt.title("Correlation Heatmap: Top 20 Variables Related to Inflation", fontsize=16)

# Roter x-labels og y-labels
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

plt.tight_layout()
#plt.savefig('')
plt.show()
